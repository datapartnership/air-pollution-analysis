# %%
# Add this at the top of your notebook
# %load_ext autoreload
# %autoreload 2  
# Automatically reload all modules before executing code

from airpollutionpy import extraction as no2
import ee
import geemap
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import sys
from datetime import datetime

# %%
no2.initialize_earth_engine()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Earth Engine already initialized

# %%
import requests 

def get_boundaries(attr, val):
    """
    This function queries World Bank official boundary dataset and returns 
    country boundary based on attribute and value passed to the function. 
    
    Input:
    attr: One of the attributes of database
    val : Value corresponding to the attribute
    
    Complete list of attributes can be found here: 
    https://services.arcgis.com/iQ1dY19aHwbSDYIF/ArcGIS/rest/services/World_Bank_Official_Boundaries_World_Country_Polygons_(Very_High_Definition)/FeatureServer/0
    
    Returns:
    A dataframe with features and geometry returned by the API. 
    """
    
    url = ''.join(['https://services.arcgis.com/iQ1dY19aHwbSDYIF/ArcGIS/rest/services/',
            'World_Bank_Official_Boundaries_World_Country_Polygons_(Very_High_Definition)/FeatureServer/0/query?',
            "where={a}='{b}'&f=pjson&returnGeometry=true&outFields=*&outSR=4326".format(a=attr, b=val)])

    result = requests.get(url)

    if result.status_code == 200:
        try:
            res = result.json()
            df = pd.DataFrame.from_dict(res['features'][0]).T[:-1]
            geom_lis = []
            for i in range(len(res['features'][0]['geometry']['rings'])):
                geom_lis.append(shapely.geometry.Polygon(res['features'][0]['geometry']['rings'][i]))
            geom = shapely.ops.cascaded_union(geom_lis)
            df.loc['attributes', 'rings'] = geom
            return df
        except Exception as e:
            return e.args[0]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# country_list = ['ETH', 'KEN']
# gdf = pd.DataFrame()
# for name in country_list:
    
#     df = get_boundaries('ISO_A3', name)
    
#     if isinstance(df, pd.DataFrame):
#         gdf = pd.concat([gdf, df])
#     elif isinstance(df, str):
#         country = san_fac.loc[name, 'Country']
#         df = get_boundaries('WB_NAME', country)
#         if isinstance(df, pd.DataFrame):
#             gdf = pd.concat([gdf, df])
#         else:
#             print(name)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
eth_adm0 = gpd.read_file('../data/boundaries/ethiopia/eth_admbnda_adm0_csa_bofedb_itos_2021.shp')
eth_adm1 = gpd.read_file('../data/boundaries/ethiopia/eth_admbnda_adm1_csa_bofedb_2021.shp')
eth_adm2 = gpd.read_file('../data/boundaries/ethiopia/eth_admbnda_adm2_csa_bofedb_2021.shp')
eth_adm3 = gpd.read_file('../data/boundaries/ethiopia/eth_admbnda_adm3_csa_bofedb_2021.shp')

eth_adm3_path = '../data/boundaries/ethiopia/eth_admbnda_adm3_csa_bofedb_2021.shp'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
start_date = '2020-01-01'
end_date = '2024-12-01'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
aoi
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <pre>&lt;ee.featurecollection.FeatureCollection object at 0x00000278C9BF0350&gt;</pre>

# %%
# Correct setup
aoi = ee.FeatureCollection('projects/ee-datalab/assets/ETH/eth_admbnda_adm3_csa_bofedb_2021')  # Keep as FeatureCollection
admin_regions = ee.FeatureCollection('projects/ee-datalab/assets/ETH/eth_admbnda_adm3_csa_bofedb_2021')  # Keep as FeatureCollection, not geometry()

monthly_data = no2.process_no2_data(
    start_date=start_date,
    end_date=end_date,
    aoi=aoi,
    admin_regions=admin_regions,
    temporal_resolution='monthly',
    spatial_resolution='admin',
    collection_type="OFFL"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing NO2 data from 2020-01-01 to 2024-12-01
# Temporal resolution: monthly
# Spatial resolution: admin
# Collection type: OFFL
# Admin regions count: 1082
# Number of available images in date range: 25301
# Processing month: 2020-01-01 to 2020-02-01
# Month 2020-01-01: Reduced regions result size: 1082
# Processing month: 2020-02-01 to 2020-03-01
# Month 2020-02-01: Reduced regions result size: 1082
# Processing month: 2020-03-01 to 2020-04-01
# Month 2020-03-01: Reduced regions result size: 1082
# Processing month: 2020-04-01 to 2020-05-01
# Month 2020-04-01: Reduced regions result size: 1082
# Processing month: 2020-05-01 to 2020-06-01
# Month 2020-05-01: Reduced regions result size: 1082
# Processing month: 2020-06-01 to 2020-07-01
# Month 2020-06-01: Reduced regions result size: 1082
# Processing month: 2020-07-01 to 2020-08-01
# Month 2020-07-01: Reduced regions result size: 1082
# Processing month: 2020-08-01 to 2020-09-01
# Month 2020-08-01: Reduced regions result size: 1082
# Processing month: 2020-09-01 to 2020-10-01
# Month 2020-09-01: Reduced regions result size: 1082
# Processing month: 2020-10-01 to 2020-11-01
# Month 2020-10-01: Reduced regions result size: 1082
# Processing month: 2020-11-01 to 2020-12-01
# Month 2020-11-01: Reduced regions result size: 1082
# Processing month: 2020-12-01 to 2021-01-01
# Month 2020-12-01: Reduced regions result size: 1082
# Processing month: 2021-01-01 to 2021-02-01
# Month 2021-01-01: Reduced regions result size: 1082
# Processing month: 2021-02-01 to 2021-03-01
# Month 2021-02-01: Reduced regions result size: 1082
# Processing month: 2021-03-01 to 2021-04-01
# Month 2021-03-01: Reduced regions result size: 1082
# Processing month: 2021-04-01 to 2021-05-01
# Month 2021-04-01: Reduced regions result size: 1082
# Processing month: 2021-05-01 to 2021-06-01
# Month 2021-05-01: Reduced regions result size: 1082
# Processing month: 2021-06-01 to 2021-07-01
# Month 2021-06-01: Reduced regions result size: 1082
# Processing month: 2021-07-01 to 2021-08-01
# Month 2021-07-01: Reduced regions result size: 1082
# Processing month: 2021-08-01 to 2021-09-01
# Month 2021-08-01: Reduced regions result size: 1082
# Processing month: 2021-09-01 to 2021-10-01
# Month 2021-09-01: Reduced regions result size: 1082
# Processing month: 2021-10-01 to 2021-11-01
# Month 2021-10-01: Reduced regions result size: 1082
# Processing month: 2021-11-01 to 2021-12-01
# Month 2021-11-01: Reduced regions result size: 1082
# Processing month: 2021-12-01 to 2022-01-01
# Month 2021-12-01: Reduced regions result size: 1082
# Processing month: 2022-01-01 to 2022-02-01
# Month 2022-01-01: Reduced regions result size: 1082
# Processing month: 2022-02-01 to 2022-03-01
# Month 2022-02-01: Reduced regions result size: 1082
# Processing month: 2022-03-01 to 2022-04-01
# Month 2022-03-01: Reduced regions result size: 1082
# Processing month: 2022-04-01 to 2022-05-01
# Month 2022-04-01: Reduced regions result size: 1082
# Processing month: 2022-05-01 to 2022-06-01
# Month 2022-05-01: Reduced regions result size: 1082
# Processing month: 2022-06-01 to 2022-07-01
# Month 2022-06-01: Reduced regions result size: 1082
# Processing month: 2022-07-01 to 2022-08-01
# Month 2022-07-01: Reduced regions result size: 1082
# Processing month: 2022-08-01 to 2022-09-01
# Month 2022-08-01: Reduced regions result size: 1082
# Processing month: 2022-09-01 to 2022-10-01
# Month 2022-09-01: Reduced regions result size: 1082
# Processing month: 2022-10-01 to 2022-11-01
# Month 2022-10-01: Reduced regions result size: 1082
# Processing month: 2022-11-01 to 2022-12-01
# Month 2022-11-01: Reduced regions result size: 1082
# Processing month: 2022-12-01 to 2023-01-01
# Month 2022-12-01: Reduced regions result size: 1082
# Processing month: 2023-01-01 to 2023-02-01
# Month 2023-01-01: Reduced regions result size: 1082
# Processing month: 2023-02-01 to 2023-03-01
# Month 2023-02-01: Reduced regions result size: 1082
# Processing month: 2023-03-01 to 2023-04-01
# Month 2023-03-01: Reduced regions result size: 1082
# Processing month: 2023-04-01 to 2023-05-01
# Month 2023-04-01: Reduced regions result size: 1082
# Processing month: 2023-05-01 to 2023-06-01
# Month 2023-05-01: Reduced regions result size: 1082
# Processing month: 2023-06-01 to 2023-07-01
# Month 2023-06-01: Reduced regions result size: 1082
# Processing month: 2023-07-01 to 2023-08-01
# Month 2023-07-01: Reduced regions result size: 1082
# Processing month: 2023-08-01 to 2023-09-01
# Month 2023-08-01: Reduced regions result size: 1082
# Processing month: 2023-09-01 to 2023-10-01
# Month 2023-09-01: Reduced regions result size: 1082
# Processing month: 2023-10-01 to 2023-11-01
# Month 2023-10-01: Reduced regions result size: 1082
# Processing month: 2023-11-01 to 2023-12-01
# Month 2023-11-01: Reduced regions result size: 1082
# Processing month: 2023-12-01 to 2024-01-01
# Month 2023-12-01: Reduced regions result size: 1082
# Processing month: 2024-01-01 to 2024-02-01
# Month 2024-01-01: Reduced regions result size: 1082
# Processing month: 2024-02-01 to 2024-03-01
# Month 2024-02-01: Reduced regions result size: 1082
# Processing month: 2024-03-01 to 2024-04-01
# Month 2024-03-01: Reduced regions result size: 1082
# Processing month: 2024-04-01 to 2024-05-01
# Month 2024-04-01: Reduced regions result size: 1082
# Processing month: 2024-05-01 to 2024-06-01
# Month 2024-05-01: Reduced regions result size: 1082
# Processing month: 2024-06-01 to 2024-07-01
# Month 2024-06-01: Reduced regions result size: 1082
# Processing month: 2024-07-01 to 2024-08-01
# Month 2024-07-01: Reduced regions result size: 1082
# Processing month: 2024-08-01 to 2024-09-01
# Month 2024-08-01: Reduced regions result size: 1082
# Processing month: 2024-09-01 to 2024-10-01
# Month 2024-09-01: Reduced regions result size: 1082
# Processing month: 2024-10-01 to 2024-11-01
# Month 2024-10-01: Reduced regions result size: 1082
# Processing month: 2024-11-01 to 2024-12-01
# Month 2024-11-01: Reduced regions result size: 1082
# Processing month: 2024-12-01 to 2025-01-01
# Month 2024-12-01: Reduced regions result size: 1082
# Final collection size: 64920 features

# %%
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
adm3 = list(eth_adm3['ADM3_EN'].unique())

monthly_df = no2.export_no2_data(
    collection=monthly_data,
    description="Monthly_NO2_Adm3",
    output_file="eth_adm3_no2_monthly.csv",
    destination="datalab-air-pollution/ETH/ADM3",
    export_type="GCS",
    return_df=False,
    admin_codes=adm3,
    admin_code_field='ADM3_EN'
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Using years: [2020, 2021, 2022, 2023, 2024]
# Splitting export by 1082 admin regions and 5 years
# Started export task for Tahtay Adiyabo in 2020
# Started export task for Laelay Adiabo in 2020
# Started export task for Zana in 2020
# Started export task for Tahtay Koraro in 2020
# Started export task for Asgede in 2020
# Started export task for Tselemti in 2020
# Started export task for Sheraro town in 2020
# Started export task for Indasilassie town in 2020
# Started export task for Selekleka in 2020
# Started export task for Seyemti Adyabo in 2020
# Started export task for Adi Daero in 2020
# Started export task for Adi Hageray in 2020
# Started export task for Tsimbla in 2020
# Started export task for Endabaguna town in 2020
# Started export task for Dima (TG) in 2020
# Started export task for May Tsebri town in 2020
# Started export task for Chila in 2020
# Started export task for Aheferom in 2020
# Started export task for Edaga arbi in 2020
# Started export task for Adwa in 2020
# Started export task for Laelay Maychew in 2020
# Started export task for Tahtay Mayechew in 2020
# Started export task for Adet in 2020
# Started export task for Kola Temben in 2020
# Started export task for Naeder in 2020
# Started export task for Abergele (TG) in 2020
# Started export task for Abi Adi town in 2020
# Started export task for Adwa town in 2020
# Started export task for Axum town in 2020
# Started export task for Rama in 2020
# Started export task for Ahsea in 2020
# Started export task for Egela in 2020
# Started export task for Hahayle in 2020
# Started export task for Endafelasi in 2020
# Started export task for Emba Sieneti in 2020
# Started export task for Enticho town in 2020
# Started export task for Keyhe tekli in 2020
# Started export task for Tanqua Melashe in 2020
# Started export task for Gulo Mekeda in 2020
# Started export task for Erob in 2020
# Started export task for Saesie in 2020
# Started export task for Ganta Afeshum in 2020
# Started export task for Hawzen in 2020
# Started export task for Kelete Awelallo in 2020
# Started export task for Atsbi in 2020
# Started export task for Adigrat town in 2020
# Started export task for Wukro town in 2020
# Started export task for Bizet in 2020
# Started export task for Edaga Hamus town in 2020
# Started export task for Hawzen town in 2020
# Started export task for Freweyni town in 2020
# Started export task for Tsaeda Emba in 2020
# Started export task for Atsbi town in 2020
# Started export task for Agulae in 2020
# Started export task for Geraleta in 2020
# Started export task for Zala Anbesa town in 2020
# Started export task for Selewa in 2020
# Started export task for Bora (TG) in 2020
# Started export task for Neqsege in 2020
# Started export task for Emba Alaje in 2020
# Started export task for Endamehoni in 2020
# Started export task for Raya Azebo in 2020
# Started export task for Raya Alamata in 2020
# Started export task for Ofla in 2020
# Started export task for Maichew town in 2020
# Started export task for Korem town in 2020
# Started export task for Alamata town in 2020
# Started export task for Mekhoni town in 2020
# Started export task for Zata in 2020
# Started export task for Chercher in 2020
# Started export task for Kafta Humera in 2020
# Started export task for Welkait in 2020
# Started export task for Tsegede (TG) in 2020
# Started export task for Setit Humera in 2020
# Started export task for May Kadra in 2020
# Started export task for Dansha town in 2020
# Started export task for Awra (TG) in 2020
# Started export task for Korarit in 2020
# Started export task for May Gaba in 2020
# Started export task for Saharti in 2020
# Started export task for Enderta in 2020
# Started export task for Hintalo in 2020
# Started export task for Degua Temben in 2020
# Started export task for Hagere Selam town in 2020
# Started export task for Samre in 2020
# Started export task for Adigudom in 2020
# Started export task for Wajirat in 2020
# Started export task for Mekelle in 2020
# Started export task for Dubti in 2020
# Started export task for Elidar in 2020
# Started export task for Asayita in 2020
# Started export task for Afambo in 2020
# Started export task for Mile in 2020
# Started export task for Chifra in 2020
# Started export task for Dubti town in 2020
# Started export task for Kori in 2020
# Started export task for Adar in 2020
# Started export task for Gerani in 2020
# Started export task for Asayita town in 2020
# Started export task for Samera Logiya town in 2020
# Started export task for Erebti in 2020
# Started export task for Kunneba in 2020
# Started export task for Abaala in 2020
# Started export task for Megale in 2020
# Started export task for Berahile in 2020
# Started export task for Dalol in 2020
# Started export task for Afdera in 2020
# Started export task for Bidu in 2020
# Started export task for Abaala town in 2020
# Started export task for Amibara in 2020
# Started export task for Awash in 2020
# Started export task for Gewane in 2020
# Started export task for Dulecha in 2020
# Started export task for Gelalu in 2020
# Started export task for Arguba in 2020
# Started export task for Hanruka in 2020
# Started export task for Awash town in 2020
# Started export task for Awra (AF) in 2020
# Started export task for Euwa in 2020
# Started export task for Teru in 2020
# Started export task for Yalo in 2020
# Started export task for Gulina in 2020
# Started export task for Telalek in 2020
# Started export task for Samurobi in 2020
# Started export task for Dawe in 2020
# Started export task for Dalefage in 2020
# Started export task for Hadelela in 2020
# Started export task for Addi Arekay in 2020
# Started export task for Beyeda in 2020
# Started export task for Janamora in 2020
# Started export task for Debark in 2020
# Started export task for Dabat in 2020
# Started export task for Dabat town in 2020
# Started export task for Telemt in 2020
# Started export task for Debark town in 2020
# Started export task for Ebenat in 2020
# Started export task for Libokemekem in 2020
# Started export task for Fogera in 2020
# Started export task for Farta in 2020
# Started export task for Lay Gayint in 2020
# Started export task for Tach Gayint in 2020
# Started export task for Semada in 2020
# Started export task for East Esite in 2020
# Started export task for Dera (AM) in 2020
# Started export task for Debre Tabor town in 2020
# Started export task for Andabet/ West Esite in 2020
# Started export task for Guna Begemider in 2020
# Started export task for Mena Meketewa in 2020
# Started export task for Sede Muja in 2020
# Started export task for Nefas Mewicha town in 2020
# Started export task for Wegeda town in 2020
# Started export task for Ebenat town in 2020
# Started export task for Hamusit town in 2020
# Started export task for Woreta town in 2020
# Started export task for Mekan Eyesuse in 2020
# Started export task for Adiss Zemen town in 2020
# Started export task for Bugna in 2020
# Started export task for Raya Kobo in 2020
# Started export task for Gidan in 2020
# Started export task for Meket in 2020
# Started export task for Wadla in 2020
# Started export task for Hara town in 2020
# Started export task for Guba Lafto in 2020
# Started export task for Habru in 2020
# Started export task for Woldiya town in 2020
# Started export task for Lasta in 2020
# Started export task for Dawunt in 2020
# Started export task for Gazo in 2020
# Started export task for Angot in 2020
# Started export task for Filakit town in 2020
# Started export task for Gashena town in 2020
# Started export task for Mersa town in 2020
# Started export task for Lalibela town in 2020
# Started export task for Kobo town in 2020
# Started export task for Argoba in 2020
# Started export task for Tenta in 2020
# Started export task for Kutaber in 2020
# Started export task for Ambasel in 2020
# Started export task for Thehulederie in 2020
# Started export task for Delanta in 2020
# Started export task for Kalu in 2020
# Started export task for Albuko in 2020
# Started export task for Dessie Zuria in 2020
# Started export task for Legambo in 2020
# Started export task for Sayint in 2020
# Started export task for Borena /Debresina in 2020
# Started export task for Kelela in 2020
# Started export task for Jama in 2020
# Started export task for Were Ilu in 2020
# Started export task for Wegde in 2020
# Started export task for Kombolcha town in 2020
# Started export task for Dessie town in 2020
# Started export task for Mehal Sayint in 2020
# Started export task for Legehida in 2020
# Started export task for Mekdela in 2020
# Started export task for Worebabu in 2020
# Started export task for Wereilu town in 2020
# Started export task for Wegel tena town in 2020
# Started export task for Degolo town in 2020
# Started export task for Kelala town in 2020
# Started export task for Akeseta town in 2020
# Started export task for Tulu Awlia in 2020
# Started export task for Harbu town in 2020
# Started export task for Mekane Selame in 2020
# Started export task for Hike town in 2020
# Started export task for Mida Woremo in 2020
# Started export task for Merhabete in 2020
# Started export task for Ensaro in 2020
# Started export task for Moretna Jiru in 2020
# Started export task for Menze Gera Midir in 2020
# Started export task for Gishe Rabel in 2020
# Started export task for Antsokiya in 2020
# Started export task for Eferatana Gidem in 2020
# Started export task for Menze Mama Midir in 2020
# Started export task for Tarema Ber in 2020
# Started export task for Mojan Wedera in 2020
# Started export task for Kewet in 2020
# Started export task for Angolelana Tera in 2020
# Started export task for Assagirt in 2020
# Started export task for Ankober in 2020
# Started export task for Hagere Mariam in 2020
# Started export task for Berehet in 2020
# Started export task for Minjar Shenkora in 2020
# Started export task for Basona Worena in 2020
# Started export task for Debre Berhan town in 2020
# Started export task for Menze Keya Gabriel in 2020
# Started export task for Menze Lalo Midir in 2020
# Started export task for Siya Debirna Wayu in 2020
# Started export task for Tulefa town in 2020
# Started export task for Arerti town in 2020
# Started export task for Molale town in 2020
# Started export task for Debre Sina town in 2020
# Started export task for Shoa Robit in 2020
# Started export task for Mehale Meda town in 2020
# Started export task for Ataye town in 2020
# Started export task for Aleme Ketma town in 2020
# Started export task for Bibugn in 2020
# Started export task for Hulet Ej Enese in 2020
# Started export task for Goncha Siso Enebse in 2020
# Started export task for Enebse Sarmder in 2020
# Started export task for Enarj Enawga in 2020
# Started export task for Enemay in 2020
# Started export task for Debay Telatgen in 2020
# Started export task for Debre Elias in 2020
# Started export task for Michakel in 2020
# Started export task for Guzamn in 2020
# Started export task for Baso Liben in 2020
# Started export task for Awabel in 2020
# Started export task for Dejen in 2020
# Started export task for Shebel Bernta in 2020
# Started export task for Debre Markos town in 2020
# Started export task for Senan in 2020
# Started export task for Aneded in 2020
# Started export task for Amanuel town in 2020
# Started export task for Sedae in 2020
# Started export task for Gundwoin town in 2020
# Started export task for Debrework town in 2020
# Started export task for Lumame town in 2020
# Started export task for Merto Lemariyam town in 2020
# Started export task for Mota Town in 2020
# Started export task for Dejen town in 2020
# Started export task for Bechena Town in 2020
# Started export task for Semen Achefer in 2020
# Started export task for Bahirdar Zuria in 2020
# Started export task for Yilmana Densa in 2020
# Started export task for Mecha in 2020
# Started export task for Sekela in 2020
# Started export task for Quarit in 2020
# Started export task for Dega Damot in 2020
# Started export task for Dembecha in 2020
# Started export task for Jabi Tehnan in 2020
# Started export task for Bure (AM) in 2020
# Started export task for Wemberma in 2020
# Started export task for Bahir Dar town in 2020
# Started export task for Debub Achefer in 2020
# Started export task for Finote Selam town in 2020
# Started export task for Debub Mecha in 2020
# Started export task for Shendi town in 2020
# Started export task for Denbecha town in 2020
# Started export task for Gonje in 2020
# Started export task for Dure Bete in 2020
# Started export task for Jiga town in 2020
# Started export task for Merawi town in 2020
# Started export task for Bure town in 2020
# Started export task for Adete town in 2020
# Started export task for Zequala in 2020
# Started export task for Sekota in 2020
# Started export task for Dehana in 2020
# Started export task for Gaz Gibla in 2020
# Started export task for Abergele (AM) in 2020
# Started export task for Sahila in 2020
# Started export task for Sekota town in 2020
# Started export task for Tsagbeji in 2020
# Started export task for Amde Work town in 2020
# Started export task for Dangila in 2020
# Started export task for Banja in 2020
# Started export task for Ankasha in 2020
# Started export task for Guangua in 2020
# Started export task for Fagta Lakoma in 2020
# Started export task for Jawi in 2020
# Started export task for Guagusa Shikudad in 2020
# Started export task for Ayehu Guwagusa in 2020
# Started export task for Agew Gimija Bet in 2020
# Started export task for Adiss Kidame town in 2020
# Started export task for Tilili town in 2020
# Started export task for Fendika town in 2020
# Started export task for Injibara town in 2020
# Started export task for Zigem in 2020
# Started export task for Dangila town in 2020
# Started export task for Chagni town in 2020
# Started export task for Dewa Cheffa in 2020
# Started export task for Bati in 2020
# Started export task for Jilye Tumuga in 2020
# Started export task for Artuma Fursi in 2020
# Started export task for Dewa Harewa in 2020
# Started export task for Kemisie town in 2020
# Started export task for Chef Robit town in 2020
# Started export task for Senbete town in 2020
# Started export task for Bati Town in 2020
# Started export task for Amba Giorgis town in 2020
# Started export task for Shawra town in 2020
# Started export task for Kolla Debba town in 2020
# Started export task for Chilga 1 in 2020
# Started export task for Tegede in 2020
# Started export task for Lay Armacho in 2020
# Started export task for Wegera in 2020
# Started export task for Gonder Zuria in 2020
# Started export task for East Dembia in 2020
# Started export task for Chilga 2 in 2020
# Started export task for Alefa in 2020
# Started export task for West Belesa in 2020
# Started export task for East Belesa in 2020
# Started export task for Gondar town in 2020
# Started export task for Masero Denb /Central Armacho in 2020
# Started export task for Tach Armacho in 2020
# Started export task for Takusa in 2020
# Started export task for Kinfaz Begela in 2020
# Started export task for West Dembiya in 2020
# Started export task for Aykel town in 2020
# Started export task for Adagn Ager Chaqo in 2020
# Started export task for Mirab Armacho in 2020
# Started export task for Metema in 2020
# Started export task for Quara in 2020
# Started export task for Midre Genet in 2020
# Started export task for Metema Yohanes town in 2020
# Started export task for Gendawuha town in 2020
# Started export task for Mana Sibu in 2020
# Started export task for Nejo in 2020
# Started export task for Gimbi in 2020
# Started export task for Lalo Asabi in 2020
# Started export task for Kiltu Kara in 2020
# Started export task for Boji Dirmeji in 2020
# Started export task for Ayira in 2020
# Started export task for Jarso (West Wellega) in 2020
# Started export task for Gudetu Kondole in 2020
# Started export task for Boji Chekorsa in 2020
# Started export task for Babo in 2020
# Started export task for Yubdo in 2020
# Started export task for Gaji in 2020
# Started export task for Haru in 2020
# Started export task for Nole Kaba in 2020
# Started export task for Begi in 2020
# Started export task for Homa in 2020
# Started export task for Sayo Nole in 2020
# Started export task for Guliso in 2020
# Started export task for Gimbi town in 2020
# Started export task for Leta Sibu in 2020
# Started export task for Mendi town in 2020
# Started export task for Nejo town in 2020
# Started export task for Limu (OR) in 2020
# Started export task for Ibantu in 2020
# Started export task for Gida Ayana in 2020
# Started export task for Haro Limu in 2020
# Started export task for Boneya Boshe in 2020
# Started export task for Wayu Tuka in 2020
# Started export task for Bila Seyo in 2020
# Started export task for Gobu Seyo in 2020
# Started export task for Sibu Sire in 2020
# Started export task for Diga in 2020
# Started export task for Sasiga in 2020
# Started export task for Leka Dulecha in 2020
# Started export task for Guto Gida in 2020
# Started export task for Jimma Arjo in 2020
# Started export task for Nunu Kumba in 2020
# Started export task for Wama Hagalo in 2020
# Started export task for Kiremu in 2020
# Started export task for Nekemte town in 2020
# Started export task for Darimu in 2020
# Started export task for Alge Sachi in 2020
# Started export task for Yayu in 2020
# Started export task for Metu Zuria in 2020
# Started export task for Ale in 2020
# Started export task for Bure (OR) in 2020
# Started export task for Sale Nono in 2020
# Started export task for Becho (Ilu Aba Bora) in 2020
# Started export task for Bilo Nopha in 2020
# Started export task for Hurumu in 2020
# Started export task for Didu in 2020
# Started export task for Halu /Huka in 2020
# Started export task for Metu town in 2020
# Started export task for Dorani in 2020
# Started export task for Limu Seka in 2020
# Started export task for Limu Kosa in 2020
# Started export task for Sekoru in 2020
# Started export task for Tiro Afeta in 2020
# Started export task for Kersa (Jimma) in 2020
# Started export task for Mena (Jimma) in 2020
# Started export task for Goma in 2020
# Started export task for Gera in 2020
# Started export task for Seka Chekorsa in 2020
# Started export task for Dedo in 2020
# Started export task for Omo Nada in 2020
# Started export task for Sigmo in 2020
# Started export task for Setema in 2020
# Started export task for Shebe Sambo in 2020
# Started export task for Chora (Jimma) in 2020
# Started export task for Gumay in 2020
# Started export task for Agaro town in 2020
# Started export task for Jimma town in 2020
# Started export task for Mancho in 2020
# Started export task for Omo Beyam in 2020
# Started export task for Botor Tolay in 2020
# Started export task for Nono Benja in 2020
# Started export task for Illu Galan in 2020
# Started export task for Ginde Beret in 2020
# Started export task for Jeldu in 2020
# Started export task for Ambo Zuria in 2020
# Started export task for Mida Kegn in 2020
# Started export task for Cheliya in 2020
# Started export task for Bako Tibe in 2020
# Started export task for Dano in 2020
# Started export task for Nono in 2020
# Started export task for Tikur Enchini in 2020
# Started export task for Dendi in 2020
# Started export task for Ejere /Addis Alem in 2020
# Started export task for Adda Berga in 2020
# Started export task for Meta Robi in 2020
# Started export task for Ambo town in 2020
# Started export task for Abuna Ginde Beret in 2020
# Started export task for Toke Kutaye in 2020
# Started export task for Jibat in 2020
# Started export task for Ifata in 2020
# Started export task for Ejersa Lafo in 2020
# Started export task for Cobi in 2020
# Started export task for Meta Walkite in 2020
# Started export task for Liban Jawi in 2020
# Started export task for Wara Jarso in 2020
# Started export task for Dera (OR) in 2020
# Started export task for Hidabu Abote in 2020
# Started export task for Kuyu in 2020
# Started export task for Degem in 2020
# Started export task for Gerar Jarso in 2020
# Started export task for Debre Libanos in 2020
# Started export task for Wuchale in 2020
# Started export task for Abichugna Gne'a in 2020
# Started export task for Kimbibit in 2020
# Started export task for Fiche town in 2020
# Started export task for Yaya Gulele in 2020
# Started export task for Jida in 2020
# Started export task for Aleltu in 2020
# Started export task for Fentale in 2020
# Started export task for Boset in 2020
# Started export task for Adama in 2020
# Started export task for Lome (OR) in 2020
# Started export task for Gimbichu in 2020
# Started export task for Ada'a in 2020
# Started export task for Dugda in 2020
# Started export task for Adama Tulu Jido Kombolcha in 2020
# Started export task for Bishoftu town in 2020
# Started export task for Bora (OR) in 2020
# Started export task for Liben Chukala in 2020
# Started export task for Adama town in 2020
# Started export task for Mojo Town in 2020
# Started export task for Metehara town in 2020
# Started export task for Merti in 2020
# Started export task for Aseko in 2020
# Started export task for Golocha in 2020
# Started export task for Jeju in 2020
# Started export task for Dodota in 2020
# Started export task for Ziway Dugda in 2020
# Started export task for Hitosa in 2020
# Started export task for Sude in 2020
# Started export task for Chole in 2020
# Started export task for Amigna in 2020
# Started export task for Seru in 2020
# Started export task for Robe in 2020
# Started export task for Tena in 2020
# Started export task for Shirka in 2020
# Started export task for Degeluna Tijo in 2020
# Started export task for Tiyo in 2020
# Started export task for Munessa in 2020
# Started export task for Limu Bilbilo in 2020
# Started export task for Guna in 2020
# Started export task for Sire in 2020
# Started export task for Lude Hitosa in 2020
# Started export task for Diksis in 2020
# Started export task for Bele Gesgar in 2020
# Started export task for Inkolo Wabe in 2020
# Started export task for Asela town in 2020
# Started export task for Shanan Kolu in 2020
# Started export task for Bekoji town in 2020
# Started export task for Mieso in 2020
# Started export task for Doba in 2020
# Started export task for Tulo (OR) in 2020
# Started export task for Mesela in 2020
# Started export task for Chiro town in 2020
# Started export task for Anchar in 2020
# Started export task for Goba Koricha in 2020
# Started export task for Habro in 2020
# Started export task for Daro Lebu in 2020
# Started export task for Boke in 2020
# Started export task for Kuni /Oda Bultum in 2020
# Started export task for Gemechis in 2020
# Started export task for Chiro Zuria in 2020
# Started export task for Bedesa in 2020
# Started export task for Hawi Gudina in 2020
# Started export task for Gumbi Bordede in 2020
# Started export task for Burqua Dhintu in 2020
# Started export task for Babile town in 2020
# Started export task for Kombolcha in 2020
# Started export task for Jarso (East Hararghe) in 2020
# Started export task for Gursum (OR) in 2020
# Started export task for Babile (OR) in 2020
# Started export task for Fedis in 2020
# Started export task for Haro Maya in 2020
# Started export task for Kurfa Chele in 2020
# Started export task for Kersa (East Hararge) in 2020
# Started export task for Meta in 2020
# Started export task for Goro Gutu in 2020
# Started export task for Deder in 2020
# Started export task for Melka Balo in 2020
# Started export task for Bedeno in 2020
# Started export task for Midhaga Tola in 2020
# Started export task for Chinaksen in 2020
# Started export task for Girawa in 2020
# Started export task for Golo Oda in 2020
# Started export task for Meyu Muleke in 2020
# Started export task for Haromaya town in 2020
# Started export task for Goro Muti in 2020
# Started export task for Deder town in 2020
# Started export task for Kumbi in 2020
# Started export task for Aweday town in 2020
# Started export task for Agarfa in 2020
# Started export task for Gasera in 2020
# Started export task for Sinana in 2020
# Started export task for Goba (OR) in 2020
# Started export task for Harena Buluk in 2020
# Started export task for Mena (Bale) in 2020
# Started export task for Meda Welabu in 2020
# Started export task for Berbere in 2020
# Started export task for Gura Damole in 2020
# Started export task for Goro (Bale) in 2020
# Started export task for Robe Town in 2020
# Started export task for Goba town in 2020
# Started export task for Dinsho in 2020
# Started export task for Yabelo in 2020
# Started export task for Arero in 2020
# Started export task for Moyale (OR) in 2020
# Started export task for Dire in 2020
# Started export task for Teltale in 2020
# Started export task for Miyo in 2020
# Started export task for Dilo in 2020
# Started export task for Dhas in 2020
# Started export task for Gomole in 2020
# Started export task for Guchi in 2020
# Started export task for Dubluk in 2020
# Started export task for Elwaya in 2020
# Started export task for Yabelo town in 2020
# Started export task for Wachile in 2020
# Started export task for Ameya in 2020
# Started export task for Wenchi in 2020
# Started export task for Waliso in 2020
# Started export task for Dawo in 2020
# Started export task for Ilu in 2020
# Started export task for Kersana Malima in 2020
# Started export task for Tole in 2020
# Started export task for Becho (SW Shewa) in 2020
# Started export task for Seden Sodo in 2020
# Started export task for Woliso town in 2020
# Started export task for Goro (SW Shewa) in 2020
# Started export task for Sodo Daci in 2020
# Started export task for Uraga in 2020
# Started export task for Bore in 2020
# Started export task for Adola in 2020
# Started export task for Wadera in 2020
# Started export task for Odo Shakiso in 2020
# Started export task for Liben in 2020
# Started export task for Dama in 2020
# Started export task for Arda Jila in 2020
# Started export task for Girja /Harenfema in 2020
# Started export task for Ana Sora in 2020
# Started export task for Saba Boru in 2020
# Started export task for Gora Dola in 2020
# Started export task for Negele town in 2020
# Started export task for Aga Wayu in 2020
# Started export task for Haro Walabu in 2020
# Started export task for Adola town in 2020
# Started export task for Gumi Idalo in 2020
# Started export task for Shakiso town in 2020
# Started export task for Bule Hora in 2020
# Started export task for Kercha in 2020
# Started export task for Hambela Wamena in 2020
# Started export task for Abaya in 2020
# Started export task for Dugda Dawa in 2020
# Started export task for Gelana (West Guji) in 2020
# Started export task for Melka Soda in 2020
# Started export task for Bule Hora town in 2020
# Started export task for Suro Berguda in 2020
# Started export task for Birbirsa Kojowa in 2020
# Started export task for Chora (Buno Bedele) in 2020
# Started export task for Dega in 2020
# Started export task for Dabo Hana in 2020
# Started export task for Gechi in 2020
# Started export task for Borecha in 2020
# Started export task for Dedesa in 2020
# Started export task for Meko in 2020
# Started export task for Bedele town in 2020
# Started export task for Bedele Zuria in 2020
# Started export task for Chwaka in 2020
# Started export task for Dodola town in 2020
# Started export task for Siraro in 2020
# Started export task for Shala in 2020
# Started export task for Arsi Negele in 2020
# Started export task for Kofele in 2020
# Started export task for Kore in 2020
# Started export task for Gedeb Asasa in 2020
# Started export task for Dodola in 2020
# Started export task for Kokosa in 2020
# Started export task for Nenesebo in 2020
# Started export task for Adaba in 2020
# Started export task for Shashemene town in 2020
# Started export task for Shashemene Zuria in 2020
# Started export task for Heban Arsi in 2020
# Started export task for Wondo in 2020
# Started export task for Bishan Guracha in 2020
# Started export task for Arsi Negele town in 2020
# Started export task for Hawa Galan in 2020
# Started export task for Yama Logi Welel in 2020
# Started export task for Dale Wabera in 2020
# Started export task for Gawo Kebe in 2020
# Started export task for Sayo in 2020
# Started export task for Denbi Dollo town in 2020
# Started export task for Anfilo in 2020
# Started export task for Dale Sadi in 2020
# Started export task for Gidami in 2020
# Started export task for Jimma Horo in 2020
# Started export task for Lalo Kile in 2020
# Started export task for Sedi Chenka in 2020
# Started export task for Horo in 2020
# Started export task for Shambu town in 2020
# Started export task for Guduru in 2020
# Started export task for Ababo in 2020
# Started export task for Abay Chomen in 2020
# Started export task for Jimma Genete in 2020
# Started export task for Jimma Rare in 2020
# Started export task for Jarte Jardega in 2020
# Started export task for Amuru in 2020
# Started export task for Abe Dongoro in 2020
# Started export task for Choman Guduru in 2020
# Started export task for Horo Buluk in 2020
# Started export task for Burayu in 2020
# Started export task for Lege Tafo-Lege Dadi town in 2020
# Started export task for Sululta town in 2020
# Started export task for Sebeta Hawas in 2020
# Started export task for Dukem in 2020
# Started export task for Sebeta town in 2020
# Started export task for Bereh in 2020
# Started export task for Akaki in 2020
# Started export task for Sululta in 2020
# Started export task for Welmera in 2020
# Started export task for Mulo in 2020
# Started export task for Sendafa town in 2020
# Started export task for Holeta town in 2020
# Started export task for Gelana (Finfine) in 2020
# Started export task for Gololcha Bale in 2020
# Started export task for Lege Hida in 2020
# Started export task for Ginir in 2020
# Started export task for Rayitu in 2020
# Started export task for Seweyna in 2020
# Started export task for Dawe Ketchen in 2020
# Started export task for Ginir town in 2020
# Started export task for Ayisha in 2020
# Started export task for Dembel in 2020
# Started export task for Shinile in 2020
# Started export task for Erer (SM) in 2020
# Started export task for Afdem in 2020
# Started export task for Hadhagala in 2020
# Started export task for Miesso in 2020
# Started export task for Gota-Biki in 2020
# Started export task for Gablalu in 2020
# Started export task for Gursum (SM) in 2020
# Started export task for Babile (SM) in 2020
# Started export task for Shabeeley in 2020
# Started export task for Aw-Bare in 2020
# Started export task for Kebribeyah in 2020
# Started export task for Harshin in 2020
# Started export task for Tuliguled in 2020
# Started export task for Goljano in 2020
# Started export task for Jigjiga town in 2020
# Started export task for Wajale town in 2020
# Started export task for Kebribayah town in 2020
# Started export task for Koran /Mulla in 2020
# Started export task for Haroreys in 2020
# Started export task for Harawo in 2020
# Started export task for Degehamedo in 2020
# Started export task for Degehabur in 2020
# Started export task for Aware in 2020
# Started export task for Gashamo in 2020
# Started export task for Gunagado in 2020
# Started export task for Bilcil-Bur in 2020
# Started export task for Degahabur town in 2020
# Started export task for Yocale in 2020
# Started export task for Daror in 2020
# Started export task for Burqod in 2020
# Started export task for Ararso in 2020
# Started export task for Dig in 2020
# Started export task for Fik in 2020
# Started export task for Salahad in 2020
# Started export task for Hamero in 2020
# Started export task for Lagahida in 2020
# Started export task for Meyumuluka in 2020
# Started export task for Qubi in 2020
# Started export task for Yahob in 2020
# Started export task for Wangey in 2020
# Started export task for Shaygosh in 2020
# Started export task for Kebridehar in 2020
# Started export task for Shilabo in 2020
# Started export task for Debeweyin in 2020
# Started export task for Marsin in 2020
# Started export task for Kebridehar town in 2020
# Started export task for Goglo in 2020
# Started export task for Lasdhankayre in 2020
# Started export task for Higloley in 2020
# Started export task for El-Ogaden in 2020
# Started export task for Bodaley in 2020
# Started export task for East Imi in 2020
# Started export task for Adadle in 2020
# Started export task for Danan in 2020
# Started export task for Gode in 2020
# Started export task for Kelafo in 2020
# Started export task for Mustahil in 2020
# Started export task for Ferfer in 2020
# Started export task for Berocano in 2020
# Started export task for Godey town in 2020
# Started export task for Elale in 2020
# Started export task for Aba-Korow in 2020
# Started export task for Danod in 2020
# Started export task for Bokh in 2020
# Started export task for Galadi in 2020
# Started export task for Warder in 2020
# Started export task for Daratole in 2020
# Started export task for Lehel-Yucub in 2020
# Started export task for Galhamur in 2020
# Started export task for Charati in 2020
# Started export task for Elkare /Serer in 2020
# Started export task for West Imi in 2020
# Started export task for Hargele in 2020
# Started export task for Barey in 2020
# Started export task for Dolobay in 2020
# Started export task for Raso in 2020
# Started export task for Kohle /Qoxle in 2020
# Started export task for God-God in 2020
# Started export task for Filtu in 2020
# Started export task for Dolo Ado in 2020
# Started export task for Goro Baqaqsa in 2020
# Started export task for Guradamole in 2020
# Started export task for Deka Suftu in 2020
# Started export task for Bokolmayo in 2020
# Started export task for Ayun in 2020
# Started export task for Elwayne in 2020
# Started export task for Garbo in 2020
# Started export task for Sagag in 2020
# Started export task for Dihun in 2020
# Started export task for Horshagah in 2020
# Started export task for Hararey in 2020
# Started export task for Moyale (SM) in 2020
# Started export task for Hudet in 2020
# Started export task for Mubarek in 2020
# Started export task for Qada Duma in 2020
# Started export task for Gilgel Beles town in 2020
# Started export task for Dangur in 2020
# Started export task for Guba in 2020
# Started export task for Wembera in 2020
# Started export task for Mandura in 2020
# Started export task for Dibate in 2020
# Started export task for Pawe in 2020
# Started export task for Bulen in 2020
# Started export task for Menge in 2020
# Started export task for Kurmuk in 2020
# Started export task for Assosa in 2020
# Started export task for Sherkole in 2020
# Started export task for Bambasi in 2020
# Started export task for Bilidigilu in 2020
# Started export task for Homosha in 2020
# Started export task for Undulu in 2020
# Started export task for Assosa town Administration in 2020
# Started export task for Kamashi town in 2020
# Started export task for Zayi in 2020
# Started export task for Sedal in 2020
# Started export task for Kamashi in 2020
# Started export task for Dembe in 2020
# Started export task for Mizyiga in 2020
# Started export task for Maokomo Special in 2020
# Started export task for Kebena in 2020
# Started export task for Abeshege in 2020
# Started export task for Ezha in 2020
# Started export task for Gedebano Gutazer Welene in 2020
# Started export task for Sodo in 2020
# Started export task for Meskan in 2020
# Started export task for Mareko in 2020
# Started export task for Endiguagn in 2020
# Started export task for Gumer in 2020
# Started export task for Cheha in 2020
# Started export task for Enemor Ener in 2020
# Started export task for Muhur Na Aklil in 2020
# Started export task for Geta in 2020
# Started export task for Welkite town in 2020
# Started export task for Butajira town in 2020
# Started export task for Emdebir town in 2020
# Started export task for Bui town in 2020
# Started export task for Misrak Meskan in 2020
# Started export task for Debub Sodo in 2020
# Started export task for Enor Ener in 2020
# Started export task for Misha in 2020
# Started export task for Gombora in 2020
# Started export task for Lemmo in 2020
# Started export task for Shashogo in 2020
# Started export task for Misrak Badawacho in 2020
# Started export task for Soro in 2020
# Started export task for Duna in 2020
# Started export task for Analemmo in 2020
# Started export task for Mirab Badowach in 2020
# Started export task for Gibe in 2020
# Started export task for Hosaena town in 2020
# Started export task for Shone Town in 2020
# Started export task for Gimbichu town in 2020
# Started export task for Jajura town in 2020
# Started export task for Ameka in 2020
# Started export task for Siraro Badawacho in 2020
# Started export task for Mirab Soro in 2020
# Started export task for Tembaro in 2020
# Started export task for Angacha in 2020
# Started export task for Kediada Gambela in 2020
# Started export task for Kacha Bira in 2020
# Started export task for Hadero Tunto in 2020
# Started export task for Doyogena in 2020
# Started export task for Damboya in 2020
# Started export task for Durame town in 2020
# Started export task for Adilo in 2020
# Started export task for Shinshincho town in 2020
# Started export task for Hadero town in 2020
# Started export task for Wenago in 2020
# Started export task for Yirgachefe in 2020
# Started export task for Kochere in 2020
# Started export task for Bule in 2020
# Started export task for Dila Zuria in 2020
# Started export task for Gedeb in 2020
# Started export task for Dila town in 2020
# Started export task for Chelelektu town in 2020
# Started export task for Rape in 2020
# Started export task for Churso in 2020
# Started export task for Gedeb town in 2020
# Started export task for Yirgachefe town in 2020
# Started export task for Boloso Sore in 2020
# Started export task for Damot Gale in 2020
# Started export task for Damot Woide in 2020
# Started export task for Humbo in 2020
# Started export task for Sodo Zuria in 2020
# Started export task for Kindo Koyesha in 2020
# Started export task for Ofa in 2020
# Started export task for Boloso Bombe in 2020
# Started export task for Damot Sore in 2020
# Started export task for Kindo Daddaye in 2020
# Started export task for Damot Pullasa in 2020
# Started export task for Duguna Fango in 2020
# Started export task for Sodo Town in 2020
# Started export task for Areka town in 2020
# Started export task for Boditi town in 2020
# Started export task for Tebela town in 2020
# Started export task for Gesuba town in 2020
# Started export task for Gununo Hamus town in 2020
# Started export task for Hobicha Abaya in 2020
# Started export task for Kawo Koisha in 2020
# Started export task for Abela Abaya in 2020
# Started export task for Bayera Koisha in 2020
# Started export task for Salamago in 2020
# Started export task for South Ari in 2020
# Started export task for North Ari in 2020
# Started export task for Hamer in 2020
# Started export task for Bena Tsemay in 2020
# Started export task for Dasenech /Kuraz in 2020
# Started export task for Malie in 2020
# Started export task for Nyngatom in 2020
# Started export task for Jinka town in 2020
# Started export task for Boko Dawula in 2020
# Started export task for Wub Ari in 2020
# Started export task for Selamber town in 2020
# Started export task for Boreda in 2020
# Started export task for Mirab Abaya in 2020
# Started export task for Chencha Zuriya in 2020
# Started export task for Ezo /Kogota in 2020
# Started export task for Dita in 2020
# Started export task for Daramalo in 2020
# Started export task for Chencha in 2020
# Started export task for Kemba in 2020
# Started export task for Kemba town in 2020
# Started export task for Gerese in 2020
# Started export task for Bonke in 2020
# Started export task for Arba Minch Zuria in 2020
# Started export task for Gacho Baba in 2020
# Started export task for Kucha Alpha in 2020
# Started export task for Garda Marta in 2020
# Started export task for Kucha in 2020
# Started export task for Arba Minch town in 2020
# Started export task for Alle Special in 2020
# Started export task for Karat town in 2020
# Started export task for Segen Zuria in 2020
# Started export task for Karat Zuria in 2020
# Started export task for Kena in 2020
# Started export task for Kulito town in 2020
# Started export task for Wera in 2020
# Started export task for Atote Ulo in 2020
# Started export task for Wera Djo in 2020
# Started export task for Melekoza in 2020
# Started export task for Denba Gofa in 2020
# Started export task for Zala in 2020
# Started export task for Uba Debre Tsehay in 2020
# Started export task for Gezei Gofa in 2020
# Started export task for O'yida in 2020
# Started export task for Sawla town in 2020
# Started export task for Bulike town in 2020
# Started export task for Melo Gada in 2020
# Started export task for Basketo SP Woreda in 2020
# Started export task for Alicho Woriro in 2020
# Started export task for Siltie in 2020
# Started export task for Lanfero in 2020
# Started export task for Mierab Azenet Berbere in 2020
# Started export task for Dalocha in 2020
# Started export task for Sankura in 2020
# Started export task for Misrak Azenet Berbere in 2020
# Started export task for Wulbareg in 2020
# Started export task for Tora town in 2020
# Started export task for Worabe town in 2020
# Started export task for Kibet town in 2020
# Started export task for Mito in 2020
# Started export task for Misrak Siltie in 2020
# Started export task for Amaro in 2020
# Started export task for Burji Special in 2020
# Started export task for Derashe Special in 2020
# Started export task for Yem SP Woreda in 2020
# Started export task for Anderacha in 2020
# Started export task for Masha in 2020
# Started export task for Yeki in 2020
# Started export task for Tepi in 2020
# Started export task for Masha town in 2020
# Started export task for Saylem in 2020
# Started export task for Gesha in 2020
# Started export task for Gewata in 2020
# Started export task for Gimbo in 2020
# Started export task for Adiyio in 2020
# Started export task for Tullo in 2020
# Started export task for Cheta in 2020
# Started export task for Decha in 2020
# Started export task for Chena in 2020
# Started export task for Bita in 2020
# Started export task for Bonga town in 2020
# Started export task for Goba (SP) in 2020
# Started export task for Shisho Ande in 2020
# Started export task for Wacha in 2020
# Started export task for Sheko in 2020
# Started export task for Gurafereda in 2020
# Started export task for Debub Bench in 2020
# Started export task for Shay Bench in 2020
# Started export task for Semen Bench in 2020
# Started export task for Gidi Bench in 2020
# Started export task for Mizan Aman town in 2020
# Started export task for Size town in 2020
# Started export task for Tocha in 2020
# Started export task for Mareka in 2020
# Started export task for Loma in 2020
# Started export task for Gena in 2020
# Started export task for Isara in 2020
# Started export task for Kachi in 2020
# Started export task for Tercha Zuriya in 2020
# Started export task for Mari Mansa in 2020
# Started export task for Disa in 2020
# Started export task for Zabagazo in 2020
# Started export task for Tercha town in 2020
# Started export task for Gesa town in 2020
# Started export task for Gachit in 2020
# Started export task for Menit Goldiye in 2020
# Started export task for Gori Gesha in 2020
# Started export task for Menit Shasha in 2020
# Started export task for Bero in 2020
# Started export task for Surma in 2020
# Started export task for Maji in 2020
# Started export task for Konta in 2020
# Started export task for Akobo in 2020
# Started export task for Lare in 2020
# Started export task for Jikawo in 2020
# Started export task for Wantawo in 2020
# Started export task for Makuey in 2020
# Started export task for Gambela National Park in 2020
# Started export task for Abobo in 2020
# Started export task for Gambela Zuria in 2020
# Started export task for Gog in 2020
# Started export task for Jore in 2020
# Started export task for Dima (GM) in 2020
# Started export task for Gambela town in 2020
# Started export task for Godere in 2020
# Started export task for Mengesh in 2020
# Started export task for Itang in 2020
# Started export task for Sofi in 2020
# Started export task for Shenkor in 2020
# Started export task for Jinela in 2020
# Started export task for Hakim in 2020
# Started export task for Erer (HR) in 2020
# Started export task for Dire Teyara in 2020
# Started export task for Amir Nur in 2020
# Started export task for Aboker in 2020
# Started export task for Abadir in 2020
# Started export task for Akaki Kality in 2020
# Started export task for Nifas Silk Lafto in 2020
# Started export task for Kolfe Keraniyo in 2020
# Started export task for Bole in 2020
# Started export task for Lideta in 2020
# Started export task for Kirkos in 2020
# Started export task for Yeka in 2020
# Started export task for Addis Ketema in 2020
# Started export task for Arada in 2020
# Started export task for Gulele in 2020
# Started export task for Lemi Kura in 2020
# Started export task for Sabian in 2020
# Started export task for Malka Jabti /M.Jebdu) in 2020
# Started export task for Legehare in 2020
# Started export task for Addis Ketema (DD) in 2020
# Started export task for Gende Kore in 2020
# Started export task for Dechatu in 2020
# Started export task for Hafat Issa in 2020
# Started export task for Kazira in 2020
# Started export task for Police Maret in 2020
# Started export task for Aseliso in 2020
# Started export task for Jeldessa in 2020
# Started export task for Wahil in 2020
# Started export task for Biyoawale in 2020
# Started export task for Shebe Dino in 2020
# Started export task for Hawassa Zuria in 2020
# Started export task for Arbegona in 2020
# Started export task for Dale in 2020
# Started export task for Aleta Wendo in 2020
# Started export task for Dara in 2020
# Started export task for Hulla in 2020
# Started export task for Bensa in 2020
# Started export task for Aroresa in 2020
# Started export task for Boricha in 2020
# Started export task for Gorche in 2020
# Started export task for Malga in 2020
# Started export task for Wonosho in 2020
# Started export task for Chire in 2020
# Started export task for Bursa in 2020
# Started export task for Aleta Chuko in 2020
# Started export task for Bona Zuria in 2020
# Started export task for Hawasa town in 2020
# Started export task for Wondo-Genet in 2020
# Started export task for Yirgalem town in 2020
# Started export task for Aleta Wondo town in 2020
# Started export task for Leku town in 2020
# Started export task for Hawela in 2020
# Started export task for Bura in 2020
# Started export task for Dara Otilicho in 2020
# Started export task for Teticha in 2020
# Started export task for Chirone in 2020
# Started export task for Shafamo in 2020
# Started export task for Chabe Gambeltu in 2020
# Started export task for Daye town in 2020
# Started export task for Hokko in 2020
# Started export task for Bilate Zuria in 2020
# Started export task for Darara in 2020
# Started export task for Daella in 2020
# Started export task for Chuko town in 2020
# Started export task for Wondo-Genet town in 2020
# Started export task for Loka Abaya in 2020
# Started export task for Tahtay Adiyabo in 2021
# Started export task for Laelay Adiabo in 2021
# Started export task for Zana in 2021
# Started export task for Tahtay Koraro in 2021
# Started export task for Asgede in 2021
# Started export task for Tselemti in 2021
# Started export task for Sheraro town in 2021
# Started export task for Indasilassie town in 2021
# Started export task for Selekleka in 2021
# Started export task for Seyemti Adyabo in 2021
# Started export task for Adi Daero in 2021
# Started export task for Adi Hageray in 2021
# Started export task for Tsimbla in 2021
# Started export task for Endabaguna town in 2021
# Started export task for Dima (TG) in 2021
# Started export task for May Tsebri town in 2021
# Started export task for Chila in 2021
# Started export task for Aheferom in 2021
# Started export task for Edaga arbi in 2021
# Started export task for Adwa in 2021
# Started export task for Laelay Maychew in 2021
# Started export task for Tahtay Mayechew in 2021
# Started export task for Adet in 2021
# Started export task for Kola Temben in 2021
# Started export task for Naeder in 2021
# Started export task for Abergele (TG) in 2021
# Started export task for Abi Adi town in 2021
# Started export task for Adwa town in 2021
# Started export task for Axum town in 2021
# Started export task for Rama in 2021
# Started export task for Ahsea in 2021
# Started export task for Egela in 2021
# Started export task for Hahayle in 2021
# Started export task for Endafelasi in 2021
# Started export task for Emba Sieneti in 2021
# Started export task for Enticho town in 2021
# Started export task for Keyhe tekli in 2021
# Started export task for Tanqua Melashe in 2021
# Started export task for Gulo Mekeda in 2021
# Started export task for Erob in 2021
# ...
# Error exporting Bena Tsemay in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dasenech /Kuraz in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Malie in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Nyngatom in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Jinka town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Boko Dawula in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wub Ari in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Selamber town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Boreda in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Mirab Abaya in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chencha Zuriya in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Ezo /Kogota in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dita in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Daramalo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chencha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kemba in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kemba town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gerese in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bonke in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Arba Minch Zuria in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gacho Baba in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kucha Alpha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Garda Marta in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kucha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Arba Minch town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Alle Special in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Karat town in 2024
# Started export task for Segen Zuria in 2024
# Started export task for Karat Zuria in 2024
# Started export task for Kena in 2024
# Started export task for Kulito town in 2024
# Started export task for Wera in 2024
# Started export task for Atote Ulo in 2024
# Error exporting Wera Djo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Melekoza in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Denba Gofa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Zala in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Uba Debre Tsehay in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gezei Gofa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting O'yida in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Sawla town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bulike town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Melo Gada in 2024
# Error exporting Basketo SP Woreda in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Alicho Woriro in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Siltie in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Lanfero in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Mierab Azenet Berbere in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dalocha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Sankura in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Misrak Azenet Berbere in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wulbareg in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Tora town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Worabe town in 2024
# Started export task for Kibet town in 2024
# Error exporting Mito in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Misrak Siltie in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Amaro in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Burji Special in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Derashe Special in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Yem SP Woreda in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Anderacha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Masha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Yeki in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Tepi in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Masha town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Saylem in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gesha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gewata in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gimbo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Adiyio in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Tullo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Cheta in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Decha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chena in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bita in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bonga town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Goba (SP) in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Shisho Ande in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wacha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Sheko in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gurafereda in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Debub Bench in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Shay Bench in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Semen Bench in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gidi Bench in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Mizan Aman town in 2024
# Started export task for Size town in 2024
# Started export task for Tocha in 2024
# Started export task for Mareka in 2024
# Started export task for Loma in 2024
# Started export task for Gena in 2024
# Error exporting Isara in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kachi in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Tercha Zuriya in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Mari Mansa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Disa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Zabagazo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Tercha town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gesa town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gachit in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Menit Goldiye in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gori Gesha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Menit Shasha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bero in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Surma in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Maji in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Konta in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Akobo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Lare in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Jikawo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wantawo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Makuey in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gambela National Park in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Abobo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gambela Zuria in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gog in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Jore in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Dima (GM) in 2024
# Started export task for Gambela town in 2024
# Started export task for Godere in 2024
# Started export task for Mengesh in 2024
# Started export task for Itang in 2024
# Started export task for Sofi in 2024
# Error exporting Shenkor in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Jinela in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Hakim in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Erer (HR) in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dire Teyara in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Amir Nur in 2024
# Error exporting Aboker in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Abadir in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Akaki Kality in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Nifas Silk Lafto in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kolfe Keraniyo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bole in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Lideta in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Kirkos in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Yeka in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Addis Ketema in 2024
# Started export task for Arada in 2024
# Started export task for Gulele in 2024
# Error exporting Lemi Kura in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Sabian in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Malka Jabti /M.Jebdu) in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Legehare in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Addis Ketema (DD) in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Gende Kore in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dechatu in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Hafat Issa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Kazira in 2024
# Started export task for Police Maret in 2024
# Error exporting Aseliso in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Jeldessa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wahil in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Biyoawale in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Shebe Dino in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Hawassa Zuria in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Arbegona in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dale in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Aleta Wendo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dara in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Hulla in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bensa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Aroresa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Boricha in 2024
# Error exporting Gorche in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Malga in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wonosho in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chire in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bursa in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Aleta Chuko in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started export task for Bona Zuria in 2024
# Started export task for Hawasa town in 2024
# Started export task for Wondo-Genet in 2024
# Error exporting Yirgalem town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Aleta Wondo town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Leku town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Hawela in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bura in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Dara Otilicho in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Teticha in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chirone in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Shafamo in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chabe Gambeltu in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Daye town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Hokko in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Bilate Zuria in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Darara in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Daella in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Chuko town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Wondo-Genet town in 2024: Too many tasks already in the queue (3000, limit 3000).
# Error exporting Loka Abaya in 2024: Too many tasks already in the queue (3000, limit 3000).
# Started 4468 export tasks in total

# %%
df = pd.read_csv("../data/airpollution/eth_adm0_no2_monthly_2024.csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from airpollutionpy import downloadgcs
import os

bucket_name = "datalab-air-pollution"
prefix = 'ETH/ADM3/'
output_folder = os.path.abspath("../data/airpollution/ethiopia/ethiopia_adm3/raw/monthly/")

os.makedirs(output_folder, exist_ok=True)

downloadgcs.download_bucket_files(bucket_name, output_folder=output_folder, prefix=prefix)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 6515 files in bucket
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Abergele (TG)_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Abi Adi town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Adigrat town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Adwa town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Ahsea_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Atsbi_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Axum town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Bizet_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Egela_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Emba Sieneti_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Endafelasi_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Enticho town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Erob_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Ganta Afeshum_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Gulo Mekeda_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Hahayle_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Hawzen_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Kelete Awelallo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Keyhe tekli_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Saesie_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Tanqua Melashe_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3//eth_adm3_no2_monthly_Wukro town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aba-Korow_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aba-Korow_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aba-Korow_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aba-Korow_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aba-Korow_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Aba-Korow_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abaala town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaala_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abaala_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ababo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ababo_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ababo_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ababo_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ababo_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ababo_2024.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abadir_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abadir_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abadir_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abadir_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abadir_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abadir_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abay Chomen_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abay Chomen_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abay Chomen_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abay Chomen_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abay Chomen_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abay Chomen_2024.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaya_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaya_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaya_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaya_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abaya_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abaya_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abe Dongoro_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abe Dongoro_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abe Dongoro_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abe Dongoro_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abe Dongoro_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abe Dongoro_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abela Abaya_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abela Abaya_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abela Abaya_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abela Abaya_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abela Abaya_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abela Abaya_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (AM)_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (AM)_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (AM)_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (AM)_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (AM)_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abergele (AM)_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (TG)_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (TG)_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (TG)_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (TG)_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abergele (TG)_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abergele (TG)_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abeshege_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abeshege_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abeshege_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abeshege_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abeshege_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abeshege_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abi Adi town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abi Adi town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abi Adi town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abi Adi town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abi Adi town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abi Adi town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abichugna Gne'a_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abichugna Gne'a_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abichugna Gne'a_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abichugna Gne'a_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abichugna Gne'a_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abichugna Gne'a_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abobo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abobo_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abobo_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abobo_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abobo_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abobo_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aboker_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aboker_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aboker_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Aboker_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Aboker_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Aboker_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abuna Ginde Beret_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abuna Ginde Beret_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abuna Ginde Beret_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abuna Ginde Beret_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Abuna Ginde Beret_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Abuna Ginde Beret_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ada'a_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ada'a_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ada'a_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ada'a_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ada'a_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Ada'a_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adaba_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adaba_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adaba_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adaba_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adaba_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adaba_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adadle_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adadle_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adadle_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adadle_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adadle_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adadle_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adagn Ager Chaqo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adagn Ager Chaqo_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adagn Ager Chaqo_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adagn Ager Chaqo_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adagn Ager Chaqo_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adagn Ager Chaqo_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama Tulu Jido Kombolcha_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama Tulu Jido Kombolcha_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama Tulu Jido Kombolcha_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama Tulu Jido Kombolcha_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama Tulu Jido Kombolcha_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adama Tulu Jido Kombolcha_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adama town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adama_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adama_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adar_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adar_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adar_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adar_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adar_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adar_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adda Berga_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adda Berga_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adda Berga_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adda Berga_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adda Berga_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adda Berga_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addi Arekay_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addi Arekay_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addi Arekay_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addi Arekay_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addi Arekay_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Addi Arekay_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema (DD)_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema (DD)_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema (DD)_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema (DD)_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema (DD)_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema (DD)_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Addis Ketema_2024.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adet_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adet_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adet_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adet_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adet_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adet_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adete town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adete town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adete town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adete town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adete town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adete town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Daero_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Daero_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Daero_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Daero_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Daero_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adi Daero_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Hageray_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Hageray_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Hageray_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Hageray_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adi Hageray_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adi Hageray_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigrat town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigrat town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigrat town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigrat town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigrat town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adigrat town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigudom_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigudom_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigudom_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigudom_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adigudom_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adigudom_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adilo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adilo_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adilo_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adilo_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adilo_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Adilo_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adiss Kidame town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adiss Kidame town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adiss Kidame town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adiss Kidame town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Adiss Kidame town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# ...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe town_2024.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Yirgachefe_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgalem town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgalem town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgalem town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yirgalem town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Yirgalem town_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Yirgalem town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yocale_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yocale_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yocale_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yocale_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yocale_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Yocale_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yubdo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yubdo_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yubdo_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yubdo_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yubdo_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Yubdo_2024.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zabagazo_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zabagazo_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zabagazo_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zabagazo_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zabagazo_2023.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zabagazo_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala Anbesa town_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala Anbesa town_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala Anbesa town_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala Anbesa town_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala Anbesa town_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zala Anbesa town_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zala_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zala_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zana_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zana_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zana_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zana_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zana_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zana_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zata_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zata_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zata_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zata_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zata_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zata_2024.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zayi_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zayi_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zayi_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zayi_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zayi_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zayi_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zequala_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zequala_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zequala_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zequala_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zequala_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zequala_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zigem_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zigem_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zigem_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zigem_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Zigem_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Zigem_2024.csv...
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ziway Dugda_2019.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ziway Dugda_2020.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ziway Dugda_2021.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ziway Dugda_2022.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Skipping ETH/ADM3/eth_adm3_no2_monthly_Ziway Dugda_2023.csv (already exists)
# c:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\data\airpollution\ethiopia\ethiopia_adm3\raw\monthly
# Downloading ETH/ADM3/eth_adm3_no2_monthly_Ziway Dugda_2024.csv...
# Download complete: 1049 files downloaded, 5465 files skipped

# %%
import glob
import pandas as pd

files = glob.glob('../data/airpollution/ethiopia/ethiopia_adm3/raw/monthly/*.csv')

final_df = pd.DataFrame()

for file in files:
    df = pd.read_csv(file)
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df.drop(columns=['system:index'], inplace=True)
    final_df = pd.concat([final_df, df], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Load your current data
# Replace 'your_file.csv' with your actual data file
df = final_df.copy()  


all_admin_regions = adm3

# Generate all monthly dates from Jan 2019 to Dec 2024
start_date = datetime(2019, 1, 1)
end_date = datetime(2024, 12, 1)
all_dates = []

current_date = start_date
while current_date <= end_date:
    all_dates.append(current_date.strftime('%Y-%m-%d'))
    # Move to next month
    if current_date.month == 12:
        current_date = datetime(current_date.year + 1, 1, 1)
    else:
        current_date = datetime(current_date.year, current_date.month + 1, 1)

# Create a complete DataFrame with all combinations of regions and dates
complete_df = pd.DataFrame([(region, date) for region in all_admin_regions for date in all_dates],
                          columns=['ADM3_EN', 'start_date'])

# Convert existing dataframe's date to string for comparison if needed
if df['start_date'].dtype != 'object':
    df['start_date'] = df['start_date'].astype(str)

# Merge to find missing entries
# First ensure both DataFrames have the same data types
df_existing = df[['ADM3_EN', 'start_date']].copy()
df_existing['exists'] = True

# Merge with complete set
merged_df = pd.merge(complete_df, df_existing, on=['ADM3_EN', 'start_date'], how='left')

# Find missing entries
missing_df = merged_df[merged_df['exists'].isna()]

# Show results
print(f"Total missing entries: {len(missing_df)}")
# print("\nSample of missing entries:")
# print(missing_df.head(10))

# # Save missing entries to a CSV file for further analysis
# missing_df.to_csv('missing_admin_date_entries.csv', index=False)

# # Optional: Count missing entries by admin region
missing_by_region = missing_df.groupby('ADM3_EN').size().reset_index(name='missing_count')
missing_by_region = missing_by_region.sort_values('missing_count', ascending=False)
print("\nMissing entries by region:")
print(missing_by_region.head(10))  # Show top 10 regions with most missing entries

# # Optional: Count missing entries by date
missing_by_date = missing_df.groupby('start_date').size().reset_index(name='missing_count')
missing_by_date = missing_by_date.sort_values('missing_count', ascending=False)
print("\nMissing entries by date:")
print(missing_by_date.head(10))  # Show top 10 dates with most missing entries
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total missing entries: 0
#
# Missing entries by region:
# Empty DataFrame
# Columns: [ADM3_EN, missing_count]
# Index: []
#
# Missing entries by date:
# Empty DataFrame
# Columns: [start_date, missing_count]
# Index: []

# %%
final_df.to_csv('../data/airpollution/ethiopia/ethiopia_adm3/processed/eth_adm3_no2_monthly_2019_2024.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
missing_admin_regions = list(missing_df['ADM3_EN'].unique())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Correct setup
aoi = ee.FeatureCollection('projects/ee-datalab/assets/ETH/eth_admbnda_adm3_csa_bofedb_2021')  # Keep as FeatureCollection
admin_regions = ee.FeatureCollection('projects/ee-datalab/assets/ETH/eth_admbnda_adm3_csa_bofedb_2021')  # Keep as FeatureCollection, not geometry()

filtered_aoi = aoi.filter(ee.Filter.inList('ADM3_EN', missing_admin_regions))
filtered_admin_regions = admin_regions.filter(ee.Filter.inList('ADM3_EN', missing_admin_regions))

monthly_data = no2.process_no2_data(
    start_date='2023-01-01',
    end_date='2024-12-01',
    aoi=filtered_aoi,
    admin_regions=filtered_admin_regions,
    temporal_resolution='monthly',
    spatial_resolution='admin',
    collection_type="OFFL"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing NO2 data from 2023-01-01 to 2024-12-01
# Temporal resolution: monthly
# Spatial resolution: admin
# Collection type: OFFL
# Admin regions count: 897
# Number of available images in date range: 9803
# Processing month: 2023-01-01 to 2023-02-01
# Month 2023-01-01: Reduced regions result size: 897
# Processing month: 2023-02-01 to 2023-03-01
# Month 2023-02-01: Reduced regions result size: 897
# Processing month: 2023-03-01 to 2023-04-01
# Month 2023-03-01: Reduced regions result size: 897
# Processing month: 2023-04-01 to 2023-05-01
# Month 2023-04-01: Reduced regions result size: 897
# Processing month: 2023-05-01 to 2023-06-01
# Month 2023-05-01: Reduced regions result size: 897
# Processing month: 2023-06-01 to 2023-07-01
# Month 2023-06-01: Reduced regions result size: 897
# Processing month: 2023-07-01 to 2023-08-01
# Month 2023-07-01: Reduced regions result size: 897
# Processing month: 2023-08-01 to 2023-09-01
# Month 2023-08-01: Reduced regions result size: 897
# Processing month: 2023-09-01 to 2023-10-01
# Month 2023-09-01: Reduced regions result size: 897
# Processing month: 2023-10-01 to 2023-11-01
# Month 2023-10-01: Reduced regions result size: 897
# Processing month: 2023-11-01 to 2023-12-01
# Month 2023-11-01: Reduced regions result size: 897
# Processing month: 2023-12-01 to 2024-01-01
# Month 2023-12-01: Reduced regions result size: 897
# Processing month: 2024-01-01 to 2024-02-01
# Month 2024-01-01: Reduced regions result size: 897
# Processing month: 2024-02-01 to 2024-03-01
# Month 2024-02-01: Reduced regions result size: 897
# Processing month: 2024-03-01 to 2024-04-01
# Month 2024-03-01: Reduced regions result size: 897
# Processing month: 2024-04-01 to 2024-05-01
# Month 2024-04-01: Reduced regions result size: 897
# Processing month: 2024-05-01 to 2024-06-01
# Month 2024-05-01: Reduced regions result size: 897
# Processing month: 2024-06-01 to 2024-07-01
# Month 2024-06-01: Reduced regions result size: 897
# Processing month: 2024-07-01 to 2024-08-01
# Month 2024-07-01: Reduced regions result size: 897
# Processing month: 2024-08-01 to 2024-09-01
# Month 2024-08-01: Reduced regions result size: 897
# Processing month: 2024-09-01 to 2024-10-01
# Month 2024-09-01: Reduced regions result size: 897
# Processing month: 2024-10-01 to 2024-11-01
# Month 2024-10-01: Reduced regions result size: 897
# Processing month: 2024-11-01 to 2024-12-01
# Month 2024-11-01: Reduced regions result size: 897
# Processing month: 2024-12-01 to 2025-01-01
# Month 2024-12-01: Reduced regions result size: 897
# Final collection size: 21528 features

# %%
    
    # Fetch the missing data using your existing function
    # You might need to adapt this depending on how your function works
    # Option 1: Fetch all data for missing regions
missing_data_df = no2.export_no2_data(
    collection=monthly_data,
    description="Missing_Monthly_NO2_Adm3",
    output_file="eth_adm3_no2_monthly.csv",
    destination="datalab-air-pollution/ETH/ADM3",
    export_type="GCS",
    return_df=True,  # Changed to True to get the data back
    admin_codes=missing_admin_regions,
    admin_code_field='ADM3_EN'
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Debug: Starting export to DataFrame
# Debug: Error getting collection info: Collection query aborted after accumulating over 5000 elements.
# Traceback (most recent call last):
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\ee\data.py", line 408, in _execute_cloud_call
#     return call.execute(num_retries=num_retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\googleapiclient\_helpers.py", line 130, in positional_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\googleapiclient\http.py", line 938, in execute
#     raise HttpError(resp, content, uri=self.uri)
# googleapiclient.errors.HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/869743898578/value:compute?prettyPrint=false&alt=json returned "Collection query aborted after accumulating over 5000 elements.". Details: "Collection query aborted after accumulating over 5000 elements.">
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\wb588851\OneDrive - WBG\Documents\air-pollution-analysis\src\airpollutionpy\extraction.py", line 397, in export_no2_data_to_dataframe
#     collection_info = collection.getInfo()
#                       ^^^^^^^^^^^^^^^^^^^^
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\ee\collection.py", line 579, in getInfo
#     return super().getInfo()
#            ^^^^^^^^^^^^^^^^^
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\ee\computedobject.py", line 107, in getInfo
#     return data.computeValue(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\ee\data.py", line 1128, in computeValue
#     return _execute_cloud_call(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\WBG\Anaconda3\envs\acled\Lib\site-packages\ee\data.py", line 410, in _execute_cloud_call
#     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ee.ee_exception.EEException: Collection query aborted after accumulating over 5000 elements.
# Using years: [2023, 2024]
# Splitting export by 897 admin regions and 2 years
# Started export task for Zana in 2023
# Started export task for Tahtay Koraro in 2023
# Started export task for Asgede in 2023
# Started export task for Tselemti in 2023
# Started export task for Sheraro town in 2023
# Started export task for Indasilassie town in 2023
# Started export task for Selekleka in 2023
# Started export task for Seyemti Adyabo in 2023
# Started export task for Adi Daero in 2023
# Started export task for Adi Hageray in 2023
# Started export task for Tsimbla in 2023
# Started export task for Aheferom in 2023
# Started export task for Edaga arbi in 2023
# Started export task for Adwa in 2023
# Started export task for Laelay Maychew in 2023
# Started export task for Tahtay Mayechew in 2023
# Started export task for Adet in 2023
# Started export task for Kola Temben in 2023
# Started export task for Naeder in 2023
# Started export task for Abergele (TG) in 2023
# Started export task for Abi Adi town in 2023
# Started export task for Adwa town in 2023
# Started export task for Rama in 2023
# Started export task for Ahsea in 2023
# Started export task for Egela in 2023
# Started export task for Hahayle in 2023
# Started export task for Endafelasi in 2023
# Started export task for Emba Sieneti in 2023
# Started export task for Erob in 2023
# Started export task for Saesie in 2023
# Started export task for Ganta Afeshum in 2023
# Started export task for Hawzen in 2023
# Started export task for Kelete Awelallo in 2023
# Started export task for Atsbi in 2023
# Started export task for Adigrat town in 2023
# Started export task for Edaga Hamus town in 2023
# Started export task for Hawzen town in 2023
# Started export task for Freweyni town in 2023
# Started export task for Tsaeda Emba in 2023
# Started export task for Atsbi town in 2023
# Started export task for Agulae in 2023
# Started export task for Geraleta in 2023
# Started export task for Zala Anbesa town in 2023
# Started export task for Selewa in 2023
# Started export task for Bora (TG) in 2023
# Started export task for Neqsege in 2023
# Started export task for Emba Alaje in 2023
# Started export task for Endamehoni in 2023
# Started export task for Raya Azebo in 2023
# Started export task for Raya Alamata in 2023
# Started export task for Ofla in 2023
# Started export task for Chercher in 2023
# Started export task for Kafta Humera in 2023
# Started export task for Welkait in 2023
# Started export task for Tsegede (TG) in 2023
# Started export task for Setit Humera in 2023
# Started export task for May Kadra in 2023
# Started export task for Dansha town in 2023
# Started export task for Awra (TG) in 2023
# Started export task for Korarit in 2023
# Started export task for May Gaba in 2023
# Started export task for Saharti in 2023
# Started export task for Enderta in 2023
# Started export task for Hintalo in 2023
# Started export task for Degua Temben in 2023
# Started export task for Hagere Selam town in 2023
# Started export task for Samre in 2023
# Started export task for Adigudom in 2023
# Started export task for Wajirat in 2023
# Started export task for Mekelle in 2023
# Started export task for Dubti in 2023
# Started export task for Elidar in 2023
# Started export task for Adar in 2023
# Started export task for Gerani in 2023
# Started export task for Asayita town in 2023
# Started export task for Samera Logiya town in 2023
# Started export task for Erebti in 2023
# Started export task for Kunneba in 2023
# Started export task for Abaala in 2023
# Started export task for Megale in 2023
# Started export task for Berahile in 2023
# Started export task for Dalol in 2023
# Started export task for Afdera in 2023
# Started export task for Bidu in 2023
# Started export task for Abaala town in 2023
# Started export task for Hanruka in 2023
# Started export task for Awash town in 2023
# Started export task for Awra (AF) in 2023
# Started export task for Euwa in 2023
# Started export task for Teru in 2023
# Started export task for Yalo in 2023
# Started export task for Gulina in 2023
# Started export task for Telalek in 2023
# Started export task for Samurobi in 2023
# Started export task for Dawe in 2023
# Started export task for Dalefage in 2023
# Started export task for Hadelela in 2023
# Started export task for Addi Arekay in 2023
# Started export task for Beyeda in 2023
# Started export task for Janamora in 2023
# Started export task for Debark in 2023
# Started export task for Dabat in 2023
# Started export task for Dabat town in 2023
# Started export task for Telemt in 2023
# Started export task for Debark town in 2023
# Started export task for Ebenat in 2023
# Started export task for Libokemekem in 2023
# Started export task for Fogera in 2023
# Started export task for Farta in 2023
# Started export task for Lay Gayint in 2023
# Started export task for Dera (AM) in 2023
# Started export task for Debre Tabor town in 2023
# Started export task for Andabet/ West Esite in 2023
# Started export task for Guna Begemider in 2023
# Started export task for Mena Meketewa in 2023
# Started export task for Sede Muja in 2023
# Started export task for Nefas Mewicha town in 2023
# Started export task for Wegeda town in 2023
# Started export task for Ebenat town in 2023
# Started export task for Hamusit town in 2023
# Started export task for Woreta town in 2023
# Started export task for Mekan Eyesuse in 2023
# Started export task for Adiss Zemen town in 2023
# Started export task for Bugna in 2023
# Started export task for Raya Kobo in 2023
# Started export task for Gidan in 2023
# Started export task for Meket in 2023
# Started export task for Wadla in 2023
# Started export task for Hara town in 2023
# Started export task for Guba Lafto in 2023
# Started export task for Habru in 2023
# Started export task for Woldiya town in 2023
# Started export task for Lasta in 2023
# Started export task for Dawunt in 2023
# Started export task for Gazo in 2023
# Started export task for Lalibela town in 2023
# Started export task for Kobo town in 2023
# Started export task for Argoba in 2023
# Started export task for Tenta in 2023
# Started export task for Kutaber in 2023
# Started export task for Ambasel in 2023
# Started export task for Thehulederie in 2023
# Started export task for Delanta in 2023
# Started export task for Albuko in 2023
# Started export task for Dessie Zuria in 2023
# Started export task for Legambo in 2023
# Started export task for Sayint in 2023
# Started export task for Borena /Debresina in 2023
# Started export task for Kelela in 2023
# Started export task for Jama in 2023
# Started export task for Were Ilu in 2023
# Started export task for Wegde in 2023
# Started export task for Kombolcha town in 2023
# Started export task for Dessie town in 2023
# Started export task for Mehal Sayint in 2023
# Started export task for Wereilu town in 2023
# Started export task for Wegel tena town in 2023
# Started export task for Degolo town in 2023
# Started export task for Kelala town in 2023
# Started export task for Akeseta town in 2023
# Started export task for Tulu Awlia in 2023
# Started export task for Harbu town in 2023
# Started export task for Mekane Selame in 2023
# Started export task for Mida Woremo in 2023
# Started export task for Merhabete in 2023
# Started export task for Ensaro in 2023
# Started export task for Moretna Jiru in 2023
# Started export task for Menze Gera Midir in 2023
# Started export task for Gishe Rabel in 2023
# Started export task for Antsokiya in 2023
# Started export task for Eferatana Gidem in 2023
# Started export task for Menze Mama Midir in 2023
# Started export task for Tarema Ber in 2023
# Started export task for Mojan Wedera in 2023
# Started export task for Ankober in 2023
# Started export task for Hagere Mariam in 2023
# Started export task for Berehet in 2023
# Started export task for Minjar Shenkora in 2023
# Started export task for Basona Worena in 2023
# Started export task for Debre Berhan town in 2023
# Started export task for Menze Keya Gabriel in 2023
# Started export task for Menze Lalo Midir in 2023
# Started export task for Siya Debirna Wayu in 2023
# Started export task for Tulefa town in 2023
# Started export task for Debre Sina town in 2023
# Started export task for Shoa Robit in 2023
# Started export task for Mehale Meda town in 2023
# Started export task for Ataye town in 2023
# Started export task for Aleme Ketma town in 2023
# Started export task for Bibugn in 2023
# Started export task for Hulet Ej Enese in 2023
# Started export task for Goncha Siso Enebse in 2023
# Started export task for Enemay in 2023
# Started export task for Debay Telatgen in 2023
# Started export task for Debre Elias in 2023
# Started export task for Michakel in 2023
# Started export task for Guzamn in 2023
# Started export task for Baso Liben in 2023
# Started export task for Awabel in 2023
# Started export task for Dejen in 2023
# Started export task for Shebel Bernta in 2023
# Started export task for Debre Markos town in 2023
# Started export task for Senan in 2023
# Started export task for Sedae in 2023
# Started export task for Gundwoin town in 2023
# Started export task for Debrework town in 2023
# Started export task for Lumame town in 2023
# Started export task for Merto Lemariyam town in 2023
# Started export task for Mota Town in 2023
# Started export task for Dejen town in 2023
# Started export task for Bechena Town in 2023
# Started export task for Semen Achefer in 2023
# Started export task for Sekela in 2023
# Started export task for Quarit in 2023
# Started export task for Dega Damot in 2023
# Started export task for Dembecha in 2023
# Started export task for Jabi Tehnan in 2023
# Started export task for Bure (AM) in 2023
# Started export task for Wemberma in 2023
# Started export task for Bahir Dar town in 2023
# Started export task for Debub Achefer in 2023
# Started export task for Finote Selam town in 2023
# Started export task for Debub Mecha in 2023
# Started export task for Shendi town in 2023
# Started export task for Jiga town in 2023
# Started export task for Merawi town in 2023
# Started export task for Bure town in 2023
# Started export task for Adete town in 2023
# Started export task for Zequala in 2023
# Started export task for Sekota in 2023
# Started export task for Dehana in 2023
# Started export task for Gaz Gibla in 2023
# Started export task for Abergele (AM) in 2023
# Started export task for Sahila in 2023
# Started export task for Sekota town in 2023
# Started export task for Tsagbeji in 2023
# Started export task for Jawi in 2023
# Started export task for Guagusa Shikudad in 2023
# Started export task for Ayehu Guwagusa in 2023
# Started export task for Adiss Kidame town in 2023
# Started export task for Tilili town in 2023
# Started export task for Fendika town in 2023
# Started export task for Injibara town in 2023
# Started export task for Zigem in 2023
# Started export task for Dangila town in 2023
# Started export task for Chagni town in 2023
# Started export task for Dewa Cheffa in 2023
# Started export task for Bati in 2023
# Started export task for Jilye Tumuga in 2023
# Started export task for Artuma Fursi in 2023
# Started export task for Dewa Harewa in 2023
# Started export task for Kemisie town in 2023
# Started export task for Kolla Debba town in 2023
# Started export task for Chilga 1 in 2023
# Started export task for Tegede in 2023
# Started export task for Lay Armacho in 2023
# Started export task for Wegera in 2023
# Started export task for Gonder Zuria in 2023
# Started export task for Alefa in 2023
# Started export task for West Belesa in 2023
# Started export task for East Belesa in 2023
# Started export task for Gondar town in 2023
# Started export task for Masero Denb /Central Armacho in 2023
# Started export task for Tach Armacho in 2023
# Started export task for Takusa in 2023
# Started export task for Kinfaz Begela in 2023
# Started export task for West Dembiya in 2023
# Started export task for Aykel town in 2023
# Started export task for Adagn Ager Chaqo in 2023
# Started export task for Mirab Armacho in 2023
# Started export task for Metema in 2023
# Started export task for Quara in 2023
# Started export task for Midre Genet in 2023
# Started export task for Metema Yohanes town in 2023
# Started export task for Gendawuha town in 2023
# Started export task for Mana Sibu in 2023
# Started export task for Nejo in 2023
# Started export task for Gimbi in 2023
# Started export task for Lalo Asabi in 2023
# Started export task for Kiltu Kara in 2023
# Started export task for Boji Dirmeji in 2023
# Started export task for Ayira in 2023
# Started export task for Jarso (West Wellega) in 2023
# Started export task for Nole Kaba in 2023
# Started export task for Begi in 2023
# Started export task for Homa in 2023
# Started export task for Sayo Nole in 2023
# Started export task for Guliso in 2023
# Started export task for Gimbi town in 2023
# Started export task for Leta Sibu in 2023
# Started export task for Mendi town in 2023
# Started export task for Nejo town in 2023
# Started export task for Limu (OR) in 2023
# Started export task for Ibantu in 2023
# Started export task for Gida Ayana in 2023
# Started export task for Haro Limu in 2023
# Started export task for Boneya Boshe in 2023
# Started export task for Wayu Tuka in 2023
# Started export task for Bila Seyo in 2023
# Started export task for Gobu Seyo in 2023
# Started export task for Sibu Sire in 2023
# Started export task for Diga in 2023
# Started export task for Kiremu in 2023
# Started export task for Nekemte town in 2023
# Started export task for Darimu in 2023
# Started export task for Alge Sachi in 2023
# Started export task for Yayu in 2023
# Started export task for Metu Zuria in 2023
# Started export task for Ale in 2023
# Started export task for Bure (OR) in 2023
# Started export task for Sale Nono in 2023
# Started export task for Becho (Ilu Aba Bora) in 2023
# Started export task for Bilo Nopha in 2023
# Started export task for Hurumu in 2023
# Started export task for Didu in 2023
# Started export task for Halu /Huka in 2023
# Started export task for Metu town in 2023
# Started export task for Dorani in 2023
# Started export task for Limu Seka in 2023
# Started export task for Limu Kosa in 2023
# Started export task for Goma in 2023
# Started export task for Gera in 2023
# Started export task for Seka Chekorsa in 2023
# Started export task for Dedo in 2023
# Started export task for Omo Nada in 2023
# Started export task for Sigmo in 2023
# Started export task for Setema in 2023
# Started export task for Shebe Sambo in 2023
# Started export task for Chora (Jimma) in 2023
# Started export task for Gumay in 2023
# Started export task for Agaro town in 2023
# Started export task for Jimma town in 2023
# Started export task for Mancho in 2023
# Started export task for Omo Beyam in 2023
# Started export task for Botor Tolay in 2023
# Started export task for Nono Benja in 2023
# Started export task for Illu Galan in 2023
# Started export task for Ginde Beret in 2023
# Started export task for Jeldu in 2023
# Started export task for Ambo Zuria in 2023
# Started export task for Mida Kegn in 2023
# Started export task for Cheliya in 2023
# Started export task for Bako Tibe in 2023
# Started export task for Adda Berga in 2023
# Started export task for Meta Robi in 2023
# Started export task for Ambo town in 2023
# Started export task for Abuna Ginde Beret in 2023
# Started export task for Toke Kutaye in 2023
# Started export task for Jibat in 2023
# Started export task for Ifata in 2023
# Started export task for Ejersa Lafo in 2023
# Started export task for Cobi in 2023
# Started export task for Meta Walkite in 2023
# Started export task for Liban Jawi in 2023
# Started export task for Wara Jarso in 2023
# Started export task for Dera (OR) in 2023
# Started export task for Hidabu Abote in 2023
# Started export task for Kuyu in 2023
# Started export task for Degem in 2023
# Started export task for Gerar Jarso in 2023
# Started export task for Debre Libanos in 2023
# Started export task for Wuchale in 2023
# Started export task for Abichugna Gne'a in 2023
# Started export task for Kimbibit in 2023
# Started export task for Boset in 2023
# Started export task for Adama in 2023
# Started export task for Lome (OR) in 2023
# Started export task for Gimbichu in 2023
# Started export task for Ada'a in 2023
# Started export task for Dugda in 2023
# Started export task for Adama Tulu Jido Kombolcha in 2023
# Started export task for Bora (OR) in 2023
# Started export task for Liben Chukala in 2023
# Started export task for Adama town in 2023
# Started export task for Mojo Town in 2023
# Started export task for Metehara town in 2023
# Started export task for Merti in 2023
# Started export task for Aseko in 2023
# Started export task for Golocha in 2023
# Started export task for Jeju in 2023
# Started export task for Dodota in 2023
# Started export task for Ziway Dugda in 2023
# Started export task for Hitosa in 2023
# Started export task for Sude in 2023
# Started export task for Chole in 2023
# Started export task for Amigna in 2023
# Started export task for Seru in 2023
# Started export task for Robe in 2023
# Started export task for Tena in 2023
# Started export task for Shirka in 2023
# Started export task for Degeluna Tijo in 2023
# Started export task for Tiyo in 2023
# Started export task for Munessa in 2023
# Started export task for Limu Bilbilo in 2023
# Started export task for Guna in 2023
# Started export task for Sire in 2023
# Started export task for Lude Hitosa in 2023
# Started export task for Diksis in 2023
# Started export task for Bele Gesgar in 2023
# Started export task for Inkolo Wabe in 2023
# Started export task for Asela town in 2023
# Started export task for Shanan Kolu in 2023
# Started export task for Chiro town in 2023
# Started export task for Anchar in 2023
# Started export task for Goba Koricha in 2023
# Started export task for Habro in 2023
# Started export task for Daro Lebu in 2023
# Started export task for Boke in 2023
# Started export task for Kuni /Oda Bultum in 2023
# Started export task for Gemechis in 2023
# Started export task for Chiro Zuria in 2023
# Started export task for Bedesa in 2023
# Started export task for Hawi Gudina in 2023
# Started export task for Gumbi Bordede in 2023
# Started export task for Burqua Dhintu in 2023
# Started export task for Babile town in 2023
# Started export task for Kombolcha in 2023
# Started export task for Jarso (East Hararghe) in 2023
# Started export task for Gursum (OR) in 2023
# Started export task for Babile (OR) in 2023
# Started export task for Fedis in 2023
# Started export task for Haro Maya in 2023
# Started export task for Kurfa Chele in 2023
# Started export task for Kersa (East Hararge) in 2023
# Started export task for Meta in 2023
# Started export task for Goro Gutu in 2023
# Started export task for Chinaksen in 2023
# Started export task for Girawa in 2023
# Started export task for Golo Oda in 2023
# Started export task for Meyu Muleke in 2023
# Started export task for Haromaya town in 2023
# Started export task for Goro Muti in 2023
# Started export task for Deder town in 2023
# Started export task for Kumbi in 2023
# Started export task for Aweday town in 2023
# Started export task for Agarfa in 2023
# Started export task for Gasera in 2023
# Started export task for Sinana in 2023
# Started export task for Goba (OR) in 2023
# Started export task for Harena Buluk in 2023
# Started export task for Mena (Bale) in 2023
# Started export task for Meda Welabu in 2023
# Started export task for Berbere in 2023
# Started export task for Gura Damole in 2023
# Started export task for Goro (Bale) in 2023
# Started export task for Robe Town in 2023
# Started export task for Goba town in 2023
# Started export task for Dinsho in 2023
# Started export task for Yabelo in 2023
# Started export task for Arero in 2023
# Started export task for Moyale (OR) in 2023
# Started export task for Dire in 2023
# Started export task for Dubluk in 2023
# Started export task for Elwaya in 2023
# Started export task for Yabelo town in 2023
# Started export task for Wachile in 2023
# Started export task for Ameya in 2023
# Started export task for Wenchi in 2023
# Started export task for Waliso in 2023
# Started export task for Dawo in 2023
# Started export task for Kersana Malima in 2023
# Started export task for Tole in 2023
# Started export task for Becho (SW Shewa) in 2023
# Started export task for Seden Sodo in 2023
# Started export task for Woliso town in 2023
# Started export task for Goro (SW Shewa) in 2023
# Started export task for Sodo Daci in 2023
# Started export task for Uraga in 2023
# Started export task for Bore in 2023
# Started export task for Adola in 2023
# Started export task for Wadera in 2023
# Started export task for Odo Shakiso in 2023
# Started export task for Liben in 2023
# Started export task for Dama in 2023
# Started export task for Arda Jila in 2023
# Started export task for Girja /Harenfema in 2023
# Started export task for Ana Sora in 2023
# Started export task for Saba Boru in 2023
# Started export task for Gora Dola in 2023
# Started export task for Negele town in 2023
# Started export task for Aga Wayu in 2023
# Started export task for Haro Walabu in 2023
# Started export task for Abaya in 2023
# Started export task for Dugda Dawa in 2023
# Started export task for Gelana (West Guji) in 2023
# Started export task for Melka Soda in 2023
# Started export task for Bule Hora town in 2023
# Started export task for Suro Berguda in 2023
# Started export task for Birbirsa Kojowa in 2023
# Started export task for Chora (Buno Bedele) in 2023
# Started export task for Dega in 2023
# Started export task for Dabo Hana in 2023
# Started export task for Gechi in 2023
# Started export task for Borecha in 2023
# Started export task for Dedesa in 2023
# Started export task for Meko in 2023
# Started export task for Bedele town in 2023
# Started export task for Bedele Zuria in 2023
# Started export task for Chwaka in 2023
# Started export task for Dodola town in 2023
# Started export task for Siraro in 2023
# Started export task for Dodola in 2023
# Started export task for Kokosa in 2023
# Started export task for Nenesebo in 2023
# Started export task for Adaba in 2023
# Started export task for Shashemene town in 2023
# Started export task for Shashemene Zuria in 2023
# Started export task for Heban Arsi in 2023
# Started export task for Wondo in 2023
# Started export task for Bishan Guracha in 2023
# Started export task for Arsi Negele town in 2023
# Started export task for Hawa Galan in 2023
# Started export task for Yama Logi Welel in 2023
# Started export task for Dale Wabera in 2023
# Started export task for Gawo Kebe in 2023
# Started export task for Sayo in 2023
# Started export task for Denbi Dollo town in 2023
# Started export task for Anfilo in 2023
# Started export task for Dale Sadi in 2023
# Started export task for Gidami in 2023
# Started export task for Jimma Horo in 2023
# Started export task for Lalo Kile in 2023
# Started export task for Sedi Chenka in 2023
# Started export task for Jimma Genete in 2023
# Started export task for Jimma Rare in 2023
# Started export task for Amuru in 2023
# Started export task for Abe Dongoro in 2023
# Started export task for Choman Guduru in 2023
# Started export task for Horo Buluk in 2023
# Started export task for Burayu in 2023
# Started export task for Lege Tafo-Lege Dadi town in 2023
# Started export task for Sululta town in 2023
# Started export task for Sebeta Hawas in 2023
# Started export task for Dukem in 2023
# Started export task for Sebeta town in 2023
# Started export task for Bereh in 2023
# Started export task for Akaki in 2023
# Started export task for Sululta in 2023
# Started export task for Welmera in 2023
# Started export task for Mulo in 2023
# Started export task for Sendafa town in 2023
# Started export task for Rayitu in 2023
# Started export task for Seweyna in 2023
# Started export task for Dawe Ketchen in 2023
# Started export task for Ginir town in 2023
# Started export task for Ayisha in 2023
# Started export task for Dembel in 2023
# Started export task for Shinile in 2023
# Started export task for Erer (SM) in 2023
# Started export task for Afdem in 2023
# Started export task for Hadhagala in 2023
# Started export task for Miesso in 2023
# Started export task for Gota-Biki in 2023
# Started export task for Gablalu in 2023
# Started export task for Gursum (SM) in 2023
# Started export task for Babile (SM) in 2023
# Started export task for Shabeeley in 2023
# Started export task for Aw-Bare in 2023
# Started export task for Kebribeyah in 2023
# Started export task for Harshin in 2023
# Started export task for Tuliguled in 2023
# Started export task for Goljano in 2023
# Started export task for Jigjiga town in 2023
# Started export task for Wajale town in 2023
# Started export task for Harawo in 2023
# Started export task for Degehamedo in 2023
# Started export task for Degehabur in 2023
# Started export task for Aware in 2023
# Started export task for Gashamo in 2023
# Started export task for Gunagado in 2023
# Started export task for Bilcil-Bur in 2023
# Started export task for Degahabur town in 2023
# Started export task for Yocale in 2023
# Started export task for Burqod in 2023
# Started export task for Ararso in 2023
# Started export task for Dig in 2023
# Started export task for Fik in 2023
# Started export task for Salahad in 2023
# Started export task for Hamero in 2023
# Started export task for Lagahida in 2023
# Started export task for Meyumuluka in 2023
# Started export task for Qubi in 2023
# Started export task for Yahob in 2023
# Started export task for Wangey in 2023
# Started export task for Debeweyin in 2023
# Started export task for Marsin in 2023
# Started export task for Kebridehar town in 2023
# Started export task for Goglo in 2023
# Started export task for Lasdhankayre in 2023
# Started export task for Higloley in 2023
# Started export task for El-Ogaden in 2023
# Started export task for Bodaley in 2023
# Started export task for East Imi in 2023
# Started export task for Adadle in 2023
# Started export task for Danan in 2023
# Started export task for Gode in 2023
# Started export task for Godey town in 2023
# Started export task for Elale in 2023
# Started export task for Aba-Korow in 2023
# Started export task for Danod in 2023
# Started export task for Bokh in 2023
# Started export task for Galadi in 2023
# Started export task for Daratole in 2023
# Started export task for Lehel-Yucub in 2023
# Started export task for Galhamur in 2023
# Started export task for Charati in 2023
# Started export task for Elkare /Serer in 2023
# Started export task for West Imi in 2023
# Started export task for Hargele in 2023
# Started export task for Barey in 2023
# Started export task for Dolobay in 2023
# Started export task for Raso in 2023
# Started export task for Kohle /Qoxle in 2023
# Started export task for God-God in 2023
# Started export task for Filtu in 2023
# Started export task for Dolo Ado in 2023
# Started export task for Goro Baqaqsa in 2023
# Started export task for Bokolmayo in 2023
# Started export task for Ayun in 2023
# Started export task for Elwayne in 2023
# Started export task for Garbo in 2023
# Started export task for Sagag in 2023
# Started export task for Dihun in 2023
# Started export task for Horshagah in 2023
# Started export task for Hararey in 2023
# Started export task for Moyale (SM) in 2023
# Started export task for Hudet in 2023
# Started export task for Mubarek in 2023
# Started export task for Qada Duma in 2023
# Started export task for Gilgel Beles town in 2023
# Started export task for Dangur in 2023
# Started export task for Guba in 2023
# Started export task for Wembera in 2023
# Started export task for Mandura in 2023
# Started export task for Dibate in 2023
# Started export task for Pawe in 2023
# Started export task for Bulen in 2023
# Started export task for Menge in 2023
# Started export task for Kurmuk in 2023
# Started export task for Assosa in 2023
# Started export task for Sherkole in 2023
# Started export task for Undulu in 2023
# Started export task for Assosa town Administration in 2023
# Started export task for Kamashi town in 2023
# Started export task for Zayi in 2023
# Started export task for Sedal in 2023
# Started export task for Kamashi in 2023
# Started export task for Dembe in 2023
# Started export task for Mizyiga in 2023
# Started export task for Maokomo Special in 2023
# Started export task for Kebena in 2023
# Started export task for Abeshege in 2023
# Started export task for Gedebano Gutazer Welene in 2023
# Started export task for Sodo in 2023
# Started export task for Meskan in 2023
# Started export task for Mareko in 2023
# Started export task for Endiguagn in 2023
# Started export task for Gumer in 2023
# Started export task for Cheha in 2023
# Started export task for Enemor Ener in 2023
# Started export task for Muhur Na Aklil in 2023
# Started export task for Geta in 2023
# Started export task for Welkite town in 2023
# Started export task for Butajira town in 2023
# Started export task for Emdebir town in 2023
# Started export task for Bui town in 2023
# Started export task for Misrak Meskan in 2023
# Started export task for Debub Sodo in 2023
# Started export task for Enor Ener in 2023
# Started export task for Misha in 2023
# Started export task for Gombora in 2023
# Started export task for Lemmo in 2023
# Started export task for Shashogo in 2023
# Started export task for Misrak Badawacho in 2023
# Started export task for Soro in 2023
# Started export task for Duna in 2023
# Started export task for Analemmo in 2023
# Started export task for Mirab Badowach in 2023
# Started export task for Gibe in 2023
# Started export task for Hosaena town in 2023
# Started export task for Siraro Badawacho in 2023
# Started export task for Mirab Soro in 2023
# Started export task for Tembaro in 2023
# Started export task for Angacha in 2023
# Started export task for Kediada Gambela in 2023
# Started export task for Kacha Bira in 2023
# Started export task for Hadero Tunto in 2023
# Started export task for Doyogena in 2023
# Started export task for Damboya in 2023
# Started export task for Durame town in 2023
# Started export task for Adilo in 2023
# Started export task for Shinshincho town in 2023
# Started export task for Hadero town in 2023
# Started export task for Wenago in 2023
# Started export task for Yirgachefe in 2023
# Started export task for Kochere in 2023
# Started export task for Bule in 2023
# Started export task for Dila Zuria in 2023
# Started export task for Gedeb in 2023
# Started export task for Dila town in 2023
# Started export task for Chelelektu town in 2023
# Started export task for Rape in 2023
# Started export task for Churso in 2023
# Started export task for Gedeb town in 2023
# Started export task for Damot Woide in 2023
# Started export task for Humbo in 2023
# Started export task for Sodo Zuria in 2023
# Started export task for Kindo Koyesha in 2023
# Started export task for Ofa in 2023
# Started export task for Boloso Bombe in 2023
# Started export task for Damot Sore in 2023
# Started export task for Kindo Daddaye in 2023
# Started export task for Duguna Fango in 2023
# Started export task for Sodo Town in 2023
# Started export task for Areka town in 2023
# Started export task for Boditi town in 2023
# Started export task for Tebela town in 2023
# Started export task for Gesuba town in 2023
# Started export task for Gununo Hamus town in 2023
# Started export task for Hobicha Abaya in 2023
# Started export task for Kawo Koisha in 2023
# Started export task for Abela Abaya in 2023
# Started export task for Bayera Koisha in 2023
# Started export task for Salamago in 2023
# Started export task for South Ari in 2023
# Started export task for North Ari in 2023
# Started export task for Hamer in 2023
# Started export task for Bena Tsemay in 2023
# Started export task for Dasenech /Kuraz in 2023
# Started export task for Malie in 2023
# Started export task for Nyngatom in 2023
# Started export task for Jinka town in 2023
# Started export task for Boko Dawula in 2023
# Started export task for Wub Ari in 2023
# Started export task for Selamber town in 2023
# Started export task for Boreda in 2023
# Started export task for Mirab Abaya in 2023
# Started export task for Chencha Zuriya in 2023
# Started export task for Ezo /Kogota in 2023
# Started export task for Dita in 2023
# Started export task for Daramalo in 2023
# Started export task for Chencha in 2023
# Started export task for Kemba in 2023
# Started export task for Kemba town in 2023
# Started export task for Gerese in 2023
# Started export task for Bonke in 2023
# Started export task for Arba Minch Zuria in 2023
# Started export task for Gacho Baba in 2023
# Started export task for Kucha Alpha in 2023
# Started export task for Garda Marta in 2023
# Started export task for Kucha in 2023
# Started export task for Arba Minch town in 2023
# Started export task for Alle Special in 2023
# Started export task for Wera Djo in 2023
# Started export task for Melekoza in 2023
# Started export task for Denba Gofa in 2023
# Started export task for Zala in 2023
# Started export task for Uba Debre Tsehay in 2023
# Started export task for Gezei Gofa in 2023
# Started export task for O'yida in 2023
# Started export task for Sawla town in 2023
# Started export task for Bulike town in 2023
# Started export task for Basketo SP Woreda in 2023
# Started export task for Alicho Woriro in 2023
# Started export task for Siltie in 2023
# Started export task for Lanfero in 2023
# Started export task for Mierab Azenet Berbere in 2023
# Started export task for Dalocha in 2023
# Started export task for Sankura in 2023
# Started export task for Misrak Azenet Berbere in 2023
# Started export task for Wulbareg in 2023
# Started export task for Tora town in 2023
# Started export task for Mito in 2023
# Started export task for Misrak Siltie in 2023
# Started export task for Amaro in 2023
# Started export task for Burji Special in 2023
# Started export task for Derashe Special in 2023
# Started export task for Yem SP Woreda in 2023
# Started export task for Anderacha in 2023
# Started export task for Masha in 2023
# Started export task for Yeki in 2023
# Started export task for Tepi in 2023
# Started export task for Masha town in 2023
# Started export task for Saylem in 2023
# Started export task for Gesha in 2023
# Started export task for Gewata in 2023
# Started export task for Gimbo in 2023
# Started export task for Adiyio in 2023
# Started export task for Tullo in 2023
# Started export task for Cheta in 2023
# Started export task for Decha in 2023
# Started export task for Chena in 2023
# Started export task for Bita in 2023
# Started export task for Bonga town in 2023
# Started export task for Goba (SP) in 2023
# Started export task for Shisho Ande in 2023
# Started export task for Wacha in 2023
# Started export task for Sheko in 2023
# Started export task for Gurafereda in 2023
# Started export task for Debub Bench in 2023
# Started export task for Shay Bench in 2023
# Started export task for Semen Bench in 2023
# Started export task for Gidi Bench in 2023
# Started export task for Isara in 2023
# Started export task for Kachi in 2023
# Started export task for Tercha Zuriya in 2023
# Started export task for Mari Mansa in 2023
# Started export task for Disa in 2023
# Started export task for Zabagazo in 2023
# Started export task for Tercha town in 2023
# Started export task for Gesa town in 2023
# Started export task for Gachit in 2023
# Started export task for Menit Goldiye in 2023
# Started export task for Gori Gesha in 2023
# Started export task for Menit Shasha in 2023
# Started export task for Bero in 2023
# Started export task for Surma in 2023
# Started export task for Maji in 2023
# Started export task for Konta in 2023
# Started export task for Akobo in 2023
# Started export task for Lare in 2023
# Started export task for Jikawo in 2023
# Started export task for Wantawo in 2023
# Started export task for Makuey in 2023
# Started export task for Gambela National Park in 2023
# Started export task for Abobo in 2023
# Started export task for Gambela Zuria in 2023
# Started export task for Gog in 2023
# Started export task for Jore in 2023
# Started export task for Dima (GM) in 2023
# Started export task for Gambela town in 2023
# Started export task for Godere in 2023
# Started export task for Mengesh in 2023
# Started export task for Shenkor in 2023
# Started export task for Jinela in 2023
# Started export task for Hakim in 2023
# Started export task for Erer (HR) in 2023
# Started export task for Dire Teyara in 2023
# Started export task for Amir Nur in 2023
# Started export task for Aboker in 2023
# Started export task for Abadir in 2023
# Started export task for Akaki Kality in 2023
# Started export task for Nifas Silk Lafto in 2023
# Started export task for Kolfe Keraniyo in 2023
# Started export task for Bole in 2023
# Started export task for Lideta in 2023
# Started export task for Kirkos in 2023
# Started export task for Yeka in 2023
# Started export task for Lemi Kura in 2023
# Started export task for Sabian in 2023
# Started export task for Malka Jabti /M.Jebdu) in 2023
# Started export task for Legehare in 2023
# Started export task for Addis Ketema (DD) in 2023
# Started export task for Gende Kore in 2023
# Started export task for Dechatu in 2023
# Started export task for Hafat Issa in 2023
# Started export task for Kazira in 2023
# Started export task for Police Maret in 2023
# Started export task for Aseliso in 2023
# Started export task for Jeldessa in 2023
# Started export task for Wahil in 2023
# Started export task for Biyoawale in 2023
# Started export task for Shebe Dino in 2023
# Started export task for Hawassa Zuria in 2023
# Started export task for Arbegona in 2023
# Started export task for Dale in 2023
# Started export task for Aleta Wendo in 2023
# Started export task for Dara in 2023
# Started export task for Hulla in 2023
# Started export task for Bensa in 2023
# Started export task for Aroresa in 2023
# Started export task for Gorche in 2023
# Started export task for Malga in 2023
# Started export task for Wonosho in 2023
# Started export task for Chire in 2023
# Started export task for Bursa in 2023
# Started export task for Aleta Chuko in 2023
# Started export task for Bona Zuria in 2023
# Started export task for Wondo-Genet in 2023
# Started export task for Yirgalem town in 2023
# Started export task for Aleta Wondo town in 2023
# Started export task for Leku town in 2023
# Started export task for Hawela in 2023
# Started export task for Bura in 2023
# Started export task for Dara Otilicho in 2023
# Started export task for Teticha in 2023
# Started export task for Chirone in 2023
# Started export task for Shafamo in 2023
# Started export task for Chabe Gambeltu in 2023
# Started export task for Daye town in 2023
# Started export task for Hokko in 2023
# Started export task for Bilate Zuria in 2023
# Started export task for Darara in 2023
# Started export task for Daella in 2023
# Started export task for Chuko town in 2023
# Started export task for Wondo-Genet town in 2023
# Started export task for Loka Abaya in 2023
# Started export task for Zana in 2024
# Started export task for Tahtay Koraro in 2024
# Started export task for Asgede in 2024
# Started export task for Tselemti in 2024
# Started export task for Sheraro town in 2024
# Started export task for Indasilassie town in 2024
# Started export task for Selekleka in 2024
# Started export task for Seyemti Adyabo in 2024
# Started export task for Adi Daero in 2024
# Started export task for Adi Hageray in 2024
# Started export task for Tsimbla in 2024
# Started export task for Aheferom in 2024
# Started export task for Edaga arbi in 2024
# Started export task for Adwa in 2024
# Started export task for Laelay Maychew in 2024
# Started export task for Tahtay Mayechew in 2024
# Started export task for Adet in 2024
# Started export task for Kola Temben in 2024
# Started export task for Naeder in 2024
# Started export task for Abergele (TG) in 2024
# Started export task for Abi Adi town in 2024
# Started export task for Adwa town in 2024
# Started export task for Rama in 2024
# Started export task for Ahsea in 2024
# Started export task for Egela in 2024
# Started export task for Hahayle in 2024
# Started export task for Endafelasi in 2024
# Started export task for Emba Sieneti in 2024
# Started export task for Erob in 2024
# Started export task for Saesie in 2024
# Started export task for Ganta Afeshum in 2024
# Started export task for Hawzen in 2024
# Started export task for Kelete Awelallo in 2024
# Started export task for Atsbi in 2024
# Started export task for Adigrat town in 2024
# Started export task for Edaga Hamus town in 2024
# Started export task for Hawzen town in 2024
# Started export task for Freweyni town in 2024
# Started export task for Tsaeda Emba in 2024
# Started export task for Atsbi town in 2024
# Started export task for Agulae in 2024
# Started export task for Geraleta in 2024
# Started export task for Zala Anbesa town in 2024
# Started export task for Selewa in 2024
# Started export task for Bora (TG) in 2024
# Started export task for Neqsege in 2024
# Started export task for Emba Alaje in 2024
# Started export task for Endamehoni in 2024
# Started export task for Raya Azebo in 2024
# Started export task for Raya Alamata in 2024
# Started export task for Ofla in 2024
# Started export task for Chercher in 2024
# Started export task for Kafta Humera in 2024
# Started export task for Welkait in 2024
# Started export task for Tsegede (TG) in 2024
# Started export task for Setit Humera in 2024
# Started export task for May Kadra in 2024
# Started export task for Dansha town in 2024
# Started export task for Awra (TG) in 2024
# Started export task for Korarit in 2024
# Started export task for May Gaba in 2024
# Started export task for Saharti in 2024
# Started export task for Enderta in 2024
# Started export task for Hintalo in 2024
# Started export task for Degua Temben in 2024
# Started export task for Hagere Selam town in 2024
# Started export task for Samre in 2024
# Started export task for Adigudom in 2024
# Started export task for Wajirat in 2024
# Started export task for Mekelle in 2024
# Started export task for Dubti in 2024
# Started export task for Elidar in 2024
# Started export task for Adar in 2024
# Started export task for Gerani in 2024
# Started export task for Asayita town in 2024
# Started export task for Samera Logiya town in 2024
# Started export task for Erebti in 2024
# Started export task for Kunneba in 2024
# Started export task for Abaala in 2024
# Started export task for Megale in 2024
# Started export task for Berahile in 2024
# Started export task for Dalol in 2024
# Started export task for Afdera in 2024
# Started export task for Bidu in 2024
# Started export task for Abaala town in 2024
# Started export task for Hanruka in 2024
# Started export task for Awash town in 2024
# Started export task for Awra (AF) in 2024
# Started export task for Euwa in 2024
# Started export task for Teru in 2024
# Started export task for Yalo in 2024
# Started export task for Gulina in 2024
# Started export task for Telalek in 2024
# Started export task for Samurobi in 2024
# Started export task for Dawe in 2024
# Started export task for Dalefage in 2024
# Started export task for Hadelela in 2024
# Started export task for Addi Arekay in 2024
# Started export task for Beyeda in 2024
# Started export task for Janamora in 2024
# Started export task for Debark in 2024
# Started export task for Dabat in 2024
# Started export task for Dabat town in 2024
# Started export task for Telemt in 2024
# Started export task for Debark town in 2024
# Started export task for Ebenat in 2024
# Started export task for Libokemekem in 2024
# Started export task for Fogera in 2024
# Started export task for Farta in 2024
# Started export task for Lay Gayint in 2024
# Started export task for Dera (AM) in 2024
# Started export task for Debre Tabor town in 2024
# Started export task for Andabet/ West Esite in 2024
# Started export task for Guna Begemider in 2024
# Started export task for Mena Meketewa in 2024
# Started export task for Sede Muja in 2024
# Started export task for Nefas Mewicha town in 2024
# Started export task for Wegeda town in 2024
# Started export task for Ebenat town in 2024
# Started export task for Hamusit town in 2024
# Started export task for Woreta town in 2024
# Started export task for Mekan Eyesuse in 2024
# Started export task for Adiss Zemen town in 2024
# Started export task for Bugna in 2024
# Started export task for Raya Kobo in 2024
# Started export task for Gidan in 2024
# Started export task for Meket in 2024
# Started export task for Wadla in 2024
# Started export task for Hara town in 2024
# Started export task for Guba Lafto in 2024
# Started export task for Habru in 2024
# Started export task for Woldiya town in 2024
# Started export task for Lasta in 2024
# Started export task for Dawunt in 2024
# Started export task for Gazo in 2024
# Started export task for Lalibela town in 2024
# Started export task for Kobo town in 2024
# Started export task for Argoba in 2024
# Started export task for Tenta in 2024
# Started export task for Kutaber in 2024
# Started export task for Ambasel in 2024
# Started export task for Thehulederie in 2024
# Started export task for Delanta in 2024
# Started export task for Albuko in 2024
# Started export task for Dessie Zuria in 2024
# Started export task for Legambo in 2024
# Started export task for Sayint in 2024
# Started export task for Borena /Debresina in 2024
# Started export task for Kelela in 2024
# Started export task for Jama in 2024
# Started export task for Were Ilu in 2024
# Started export task for Wegde in 2024
# Started export task for Kombolcha town in 2024
# Started export task for Dessie town in 2024
# Started export task for Mehal Sayint in 2024
# Started export task for Wereilu town in 2024
# Started export task for Wegel tena town in 2024
# Started export task for Degolo town in 2024
# Started export task for Kelala town in 2024
# Started export task for Akeseta town in 2024
# Started export task for Tulu Awlia in 2024
# Started export task for Harbu town in 2024
# Started export task for Mekane Selame in 2024
# Started export task for Mida Woremo in 2024
# Started export task for Merhabete in 2024
# Started export task for Ensaro in 2024
# Started export task for Moretna Jiru in 2024
# Started export task for Menze Gera Midir in 2024
# Started export task for Gishe Rabel in 2024
# Started export task for Antsokiya in 2024
# Started export task for Eferatana Gidem in 2024
# Started export task for Menze Mama Midir in 2024
# Started export task for Tarema Ber in 2024
# Started export task for Mojan Wedera in 2024
# ...
# Started export task for Dale Wabera in 2024
# Started export task for Gawo Kebe in 2024
# Started export task for Sayo in 2024
# Started export task for Denbi Dollo town in 2024
# Started export task for Anfilo in 2024
# Started export task for Dale Sadi in 2024
# Started export task for Gidami in 2024
# Started export task for Jimma Horo in 2024
# Started export task for Lalo Kile in 2024
# Started export task for Sedi Chenka in 2024
# Started export task for Jimma Genete in 2024
# Started export task for Jimma Rare in 2024
# Started export task for Amuru in 2024
# Started export task for Abe Dongoro in 2024
# Started export task for Choman Guduru in 2024
# Started export task for Horo Buluk in 2024
# Started export task for Burayu in 2024
# Started export task for Lege Tafo-Lege Dadi town in 2024
# Started export task for Sululta town in 2024
# Started export task for Sebeta Hawas in 2024
# Started export task for Dukem in 2024
# Started export task for Sebeta town in 2024
# Started export task for Bereh in 2024
# Started export task for Akaki in 2024
# Started export task for Sululta in 2024
# Started export task for Welmera in 2024
# Started export task for Mulo in 2024
# Started export task for Sendafa town in 2024
# Started export task for Rayitu in 2024
# Started export task for Seweyna in 2024
# Started export task for Dawe Ketchen in 2024
# Started export task for Ginir town in 2024
# Started export task for Ayisha in 2024
# Started export task for Dembel in 2024
# Started export task for Shinile in 2024
# Started export task for Erer (SM) in 2024
# Started export task for Afdem in 2024
# Started export task for Hadhagala in 2024
# Started export task for Miesso in 2024
# Started export task for Gota-Biki in 2024
# Started export task for Gablalu in 2024
# Started export task for Gursum (SM) in 2024
# Started export task for Babile (SM) in 2024
# Started export task for Shabeeley in 2024
# Started export task for Aw-Bare in 2024
# Started export task for Kebribeyah in 2024
# Started export task for Harshin in 2024
# Started export task for Tuliguled in 2024
# Started export task for Goljano in 2024
# Started export task for Jigjiga town in 2024
# Started export task for Wajale town in 2024
# Started export task for Harawo in 2024
# Started export task for Degehamedo in 2024
# Started export task for Degehabur in 2024
# Started export task for Aware in 2024
# Started export task for Gashamo in 2024
# Started export task for Gunagado in 2024
# Started export task for Bilcil-Bur in 2024
# Started export task for Degahabur town in 2024
# Started export task for Yocale in 2024
# Started export task for Burqod in 2024
# Started export task for Ararso in 2024
# Started export task for Dig in 2024
# Started export task for Fik in 2024
# Started export task for Salahad in 2024
# Started export task for Hamero in 2024
# Started export task for Lagahida in 2024
# Started export task for Meyumuluka in 2024
# Started export task for Qubi in 2024
# Started export task for Yahob in 2024
# Started export task for Wangey in 2024
# Started export task for Debeweyin in 2024
# Started export task for Marsin in 2024
# Started export task for Kebridehar town in 2024
# Started export task for Goglo in 2024
# Started export task for Lasdhankayre in 2024
# Started export task for Higloley in 2024
# Started export task for El-Ogaden in 2024
# Started export task for Bodaley in 2024
# Started export task for East Imi in 2024
# Started export task for Adadle in 2024
# Started export task for Danan in 2024
# Started export task for Gode in 2024
# Started export task for Godey town in 2024
# Started export task for Elale in 2024
# Started export task for Aba-Korow in 2024
# Started export task for Danod in 2024
# Started export task for Bokh in 2024
# Started export task for Galadi in 2024
# Started export task for Daratole in 2024
# Started export task for Lehel-Yucub in 2024
# Started export task for Galhamur in 2024
# Started export task for Charati in 2024
# Started export task for Elkare /Serer in 2024
# Started export task for West Imi in 2024
# Started export task for Hargele in 2024
# Started export task for Barey in 2024
# Started export task for Dolobay in 2024
# Started export task for Raso in 2024
# Started export task for Kohle /Qoxle in 2024
# Started export task for God-God in 2024
# Started export task for Filtu in 2024
# Started export task for Dolo Ado in 2024
# Started export task for Goro Baqaqsa in 2024
# Started export task for Bokolmayo in 2024
# Started export task for Ayun in 2024
# Started export task for Elwayne in 2024
# Started export task for Garbo in 2024
# Started export task for Sagag in 2024
# Started export task for Dihun in 2024
# Started export task for Horshagah in 2024
# Started export task for Hararey in 2024
# Started export task for Moyale (SM) in 2024
# Started export task for Hudet in 2024
# Started export task for Mubarek in 2024
# Started export task for Qada Duma in 2024
# Started export task for Gilgel Beles town in 2024
# Started export task for Dangur in 2024
# Started export task for Guba in 2024
# Started export task for Wembera in 2024
# Started export task for Mandura in 2024
# Started export task for Dibate in 2024
# Started export task for Pawe in 2024
# Started export task for Bulen in 2024
# Started export task for Menge in 2024
# Started export task for Kurmuk in 2024
# Started export task for Assosa in 2024
# Started export task for Sherkole in 2024
# Started export task for Undulu in 2024
# Started export task for Assosa town Administration in 2024
# Started export task for Kamashi town in 2024
# Started export task for Zayi in 2024
# Started export task for Sedal in 2024
# Started export task for Kamashi in 2024
# Started export task for Dembe in 2024
# Started export task for Mizyiga in 2024
# Started export task for Maokomo Special in 2024
# Started export task for Kebena in 2024
# Started export task for Abeshege in 2024
# Started export task for Gedebano Gutazer Welene in 2024
# Started export task for Sodo in 2024
# Started export task for Meskan in 2024
# Started export task for Mareko in 2024
# Started export task for Endiguagn in 2024
# Started export task for Gumer in 2024
# Started export task for Cheha in 2024
# Started export task for Enemor Ener in 2024
# Started export task for Muhur Na Aklil in 2024
# Started export task for Geta in 2024
# Started export task for Welkite town in 2024
# Started export task for Butajira town in 2024
# Started export task for Emdebir town in 2024
# Started export task for Bui town in 2024
# Started export task for Misrak Meskan in 2024
# Started export task for Debub Sodo in 2024
# Started export task for Enor Ener in 2024
# Started export task for Misha in 2024
# Started export task for Gombora in 2024
# Started export task for Lemmo in 2024
# Started export task for Shashogo in 2024
# Started export task for Misrak Badawacho in 2024
# Started export task for Soro in 2024
# Started export task for Duna in 2024
# Started export task for Analemmo in 2024
# Started export task for Mirab Badowach in 2024
# Started export task for Gibe in 2024
# Started export task for Hosaena town in 2024
# Started export task for Siraro Badawacho in 2024
# Started export task for Mirab Soro in 2024
# Started export task for Tembaro in 2024
# Started export task for Angacha in 2024
# Started export task for Kediada Gambela in 2024
# Started export task for Kacha Bira in 2024
# Started export task for Hadero Tunto in 2024
# Started export task for Doyogena in 2024
# Started export task for Damboya in 2024
# Started export task for Durame town in 2024
# Started export task for Adilo in 2024
# Started export task for Shinshincho town in 2024
# Started export task for Hadero town in 2024
# Started export task for Wenago in 2024
# Started export task for Yirgachefe in 2024
# Started export task for Kochere in 2024
# Started export task for Bule in 2024
# Started export task for Dila Zuria in 2024
# Started export task for Gedeb in 2024
# Started export task for Dila town in 2024
# Started export task for Chelelektu town in 2024
# Started export task for Rape in 2024
# Started export task for Churso in 2024
# Started export task for Gedeb town in 2024
# Started export task for Damot Woide in 2024
# Started export task for Humbo in 2024
# Started export task for Sodo Zuria in 2024
# Started export task for Kindo Koyesha in 2024
# Started export task for Ofa in 2024
# Started export task for Boloso Bombe in 2024
# Started export task for Damot Sore in 2024
# Started export task for Kindo Daddaye in 2024
# Started export task for Duguna Fango in 2024
# Started export task for Sodo Town in 2024
# Started export task for Areka town in 2024
# Started export task for Boditi town in 2024
# Started export task for Tebela town in 2024
# Started export task for Gesuba town in 2024
# Started export task for Gununo Hamus town in 2024
# Started export task for Hobicha Abaya in 2024
# Started export task for Kawo Koisha in 2024
# Started export task for Abela Abaya in 2024
# Started export task for Bayera Koisha in 2024
# Started export task for Salamago in 2024
# Started export task for South Ari in 2024
# Started export task for North Ari in 2024
# Started export task for Hamer in 2024
# Started export task for Bena Tsemay in 2024
# Started export task for Dasenech /Kuraz in 2024
# Started export task for Malie in 2024
# Started export task for Nyngatom in 2024
# Started export task for Jinka town in 2024
# Started export task for Boko Dawula in 2024
# Started export task for Wub Ari in 2024
# Started export task for Selamber town in 2024
# Started export task for Boreda in 2024
# Started export task for Mirab Abaya in 2024
# Started export task for Chencha Zuriya in 2024
# Started export task for Ezo /Kogota in 2024
# Started export task for Dita in 2024
# Started export task for Daramalo in 2024
# Started export task for Chencha in 2024
# Started export task for Kemba in 2024
# Started export task for Kemba town in 2024
# Started export task for Gerese in 2024
# Started export task for Bonke in 2024
# Started export task for Arba Minch Zuria in 2024
# Started export task for Gacho Baba in 2024
# Started export task for Kucha Alpha in 2024
# Started export task for Garda Marta in 2024
# Started export task for Kucha in 2024
# Started export task for Arba Minch town in 2024
# Started export task for Alle Special in 2024
# Started export task for Wera Djo in 2024
# Started export task for Melekoza in 2024
# Started export task for Denba Gofa in 2024
# Started export task for Zala in 2024
# Started export task for Uba Debre Tsehay in 2024
# Started export task for Gezei Gofa in 2024
# Started export task for O'yida in 2024
# Started export task for Sawla town in 2024
# Started export task for Bulike town in 2024
# Started export task for Basketo SP Woreda in 2024
# Started export task for Alicho Woriro in 2024
# Started export task for Siltie in 2024
# Started export task for Lanfero in 2024
# Started export task for Mierab Azenet Berbere in 2024
# Started export task for Dalocha in 2024
# Started export task for Sankura in 2024
# Started export task for Misrak Azenet Berbere in 2024
# Started export task for Wulbareg in 2024
# Started export task for Tora town in 2024
# Started export task for Mito in 2024
# Started export task for Misrak Siltie in 2024
# Started export task for Amaro in 2024
# Started export task for Burji Special in 2024
# Started export task for Derashe Special in 2024
# Started export task for Yem SP Woreda in 2024
# Started export task for Anderacha in 2024
# Started export task for Masha in 2024
# Started export task for Yeki in 2024
# Started export task for Tepi in 2024
# Started export task for Masha town in 2024
# Started export task for Saylem in 2024
# Started export task for Gesha in 2024
# Started export task for Gewata in 2024
# Started export task for Gimbo in 2024
# Started export task for Adiyio in 2024
# Started export task for Tullo in 2024
# Started export task for Cheta in 2024
# Started export task for Decha in 2024
# Started export task for Chena in 2024
# Started export task for Bita in 2024
# Started export task for Bonga town in 2024
# Started export task for Goba (SP) in 2024
# Started export task for Shisho Ande in 2024
# Started export task for Wacha in 2024
# Started export task for Sheko in 2024
# Started export task for Gurafereda in 2024
# Started export task for Debub Bench in 2024
# Started export task for Shay Bench in 2024
# Started export task for Semen Bench in 2024
# Started export task for Gidi Bench in 2024
# Started export task for Isara in 2024
# Started export task for Kachi in 2024
# Started export task for Tercha Zuriya in 2024
# Started export task for Mari Mansa in 2024
# Started export task for Disa in 2024
# Started export task for Zabagazo in 2024
# Started export task for Tercha town in 2024
# Started export task for Gesa town in 2024
# Started export task for Gachit in 2024
# Started export task for Menit Goldiye in 2024
# Started export task for Gori Gesha in 2024
# Started export task for Menit Shasha in 2024
# Started export task for Bero in 2024
# Started export task for Surma in 2024
# Started export task for Maji in 2024
# Started export task for Konta in 2024
# Started export task for Akobo in 2024
# Started export task for Lare in 2024
# Started export task for Jikawo in 2024
# Started export task for Wantawo in 2024
# Started export task for Makuey in 2024
# Started export task for Gambela National Park in 2024
# Started export task for Abobo in 2024
# Started export task for Gambela Zuria in 2024
# Started export task for Gog in 2024
# Started export task for Jore in 2024
# Started export task for Dima (GM) in 2024
# Started export task for Gambela town in 2024
# Started export task for Godere in 2024
# Started export task for Mengesh in 2024
# Started export task for Shenkor in 2024
# Started export task for Jinela in 2024
# Started export task for Hakim in 2024
# Started export task for Erer (HR) in 2024
# Started export task for Dire Teyara in 2024
# Started export task for Amir Nur in 2024
# Started export task for Aboker in 2024
# Started export task for Abadir in 2024
# Started export task for Akaki Kality in 2024
# Started export task for Nifas Silk Lafto in 2024
# Started export task for Kolfe Keraniyo in 2024
# Started export task for Bole in 2024
# Started export task for Lideta in 2024
# Started export task for Kirkos in 2024
# Started export task for Yeka in 2024
# Started export task for Lemi Kura in 2024
# Started export task for Sabian in 2024
# Started export task for Malka Jabti /M.Jebdu) in 2024
# Started export task for Legehare in 2024
# Started export task for Addis Ketema (DD) in 2024
# Started export task for Gende Kore in 2024
# Started export task for Dechatu in 2024
# Started export task for Hafat Issa in 2024
# Started export task for Kazira in 2024
# Started export task for Police Maret in 2024
# Started export task for Aseliso in 2024
# Started export task for Jeldessa in 2024
# Started export task for Wahil in 2024
# Started export task for Biyoawale in 2024
# Started export task for Shebe Dino in 2024
# Started export task for Hawassa Zuria in 2024
# Started export task for Arbegona in 2024
# Started export task for Dale in 2024
# Started export task for Aleta Wendo in 2024
# Started export task for Dara in 2024
# Started export task for Hulla in 2024
# Started export task for Bensa in 2024
# Started export task for Aroresa in 2024
# Started export task for Gorche in 2024
# Started export task for Malga in 2024
# Started export task for Wonosho in 2024
# Started export task for Chire in 2024
# Started export task for Bursa in 2024
# Started export task for Aleta Chuko in 2024
# Started export task for Bona Zuria in 2024
# Started export task for Wondo-Genet in 2024
# Started export task for Yirgalem town in 2024
# Started export task for Aleta Wondo town in 2024
# Started export task for Leku town in 2024
# Started export task for Hawela in 2024
# Started export task for Bura in 2024
# Started export task for Dara Otilicho in 2024
# Started export task for Teticha in 2024
# Started export task for Chirone in 2024
# Started export task for Shafamo in 2024
# Started export task for Chabe Gambeltu in 2024
# Started export task for Daye town in 2024
# Started export task for Hokko in 2024
# Started export task for Bilate Zuria in 2024
# Started export task for Darara in 2024
# Started export task for Daella in 2024
# Started export task for Chuko town in 2024
# Started export task for Wondo-Genet town in 2024
# Started export task for Loka Abaya in 2024
# Started 1794 export tasks in total

# %%
missing_by_region
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#          ADM3_EN  missing_count
# 198        Chire             24
# 155         Bole             24
# 55   Aleta Chuko             24
# 3         Abadir             24
# 56   Aleta Wendo             24
# ..           ...            ...
# 892         Zana             12
# 893         Zayi             12
# 894      Zequala             12
# 895        Zigem             12
# 16         Adaba             12
#
# [897 rows x 2 columns]

# %%
missing_by_date['start_date'].max()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# '2024-12-01'
